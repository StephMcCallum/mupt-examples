# %% [markdown]
# ### Notebook for initializing polymer systems using a DPD potential

# %% [markdown]
# Environment: conda install flowermd

# %%
import matplotlib
import numpy as np  
import gsd, gsd.hoomd 
import hoomd 
import time
import matplotlib_inline
import matplotlib.pyplot as plt
import freud
import math
# %matplotlib inline
matplotlib.style.use("ggplot")
matplotlib_inline.backend_inline.set_matplotlib_formats("svg")

# %%
from flowermd.base import Pack,Lattice, Simulation,BaseHOOMDForcefield,Polymer, forcefield
from flowermd.base.system import System
from flowermd.library import forcefields, PolyEthylene
# Out:
# /Users/stephaniemccallum/miniforge3/envs/flowermd/lib/python3.12/site-packages/gmso/core/element.py:10: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import resource_filename

# %%
class DPD_AA_FF(BaseHOOMDForcefield):
    def __init__(
        self,
        epsilon,
        A,
        gamma,
        kT,
        r_cut,
        bond_k,
        bond_r0,
        angle_k,
        angle_theta0,
        torsion_c0,
        torsion_c2,
    ):
        self.epsilon = epsilon
        self.gamma = gamma
        self.A = A
        self.kT = kT
        self.r_cut = r_cut
        self.bond_k = bond_k
        self.bond_r0 = bond_r0
        self.angle_k = angle_k
        self.angle_theta0 = angle_theta0
        self.torsion_c0 = torsion_c0
        self.torsion_c2 = torsion_c2
        hoomd_forces = self._create_forcefield()
        super(DPD_AA_FF, self).__init__(hoomd_forces)

    def _create_forcefield(self):
        forces = []
        #opls = forcefields.FF_from_file('pps_opls.xml')
        #print(opls)
        #forces.append(opls.hoomd_forces)
        #use non-bonded epsilons and sigmas to scale A and gamma for each atom type
        #use bonds, angles, and dihedrals as is
        # add bonds, angles and dihedrals to the hoomd simulation
        nlist = hoomd.md.nlist.Cell(buffer=0.40, exclusions=["body"])
        dpd = hoomd.md.pair.DPD(nlist=nlist,kT=self.kT,default_r_cut=self.r_cut)
        for pair in [ #zero pairs for hydrogen interactions
            ("H", "H"),
            ("H", "C"),
            ("H", "S"),
        ]:
            dpd.params[pair] = dict(A=0,gamma=0.1)
            dpd.params[pair].r_cut = 0.0

        dpd.params[("C","C")] = dict(A=self.A,gamma=self.gamma)
        dpd.params[("C","C")].r_cut = self.r_cut
        forces.append(dpd)

        #use bonds, angles, and dihedrals from file if possible
        # add bonds, angles and dihedrals to the hoomd simulation
        bond = hoomd.md.bond.Harmonic()
        bond.params["H-C"] = dict(k=self.bond_k, r0=self.bond_r0)
        bond.params["C-H"] = dict(k=self.bond_k, r0=self.bond_r0)
        bond.params["C-C"] = dict(k=self.bond_k, r0=self.bond_r0)
        bond.params["C-S"] = dict(k=self.bond_k, r0=self.bond_r0)
        bond.params["S-H"] = dict(k=self.bond_k, r0=self.bond_r0)
        bond.params["S-S"] = dict(k=0, r0=0)
        bond.params["H-H"] = dict(k=0, r0=0)
        forces.append(bond)

        angle = hoomd.md.angle.Harmonic()
        angle.params["C-C-C"] = dict(k=self.angle_k, t0=self.angle_theta0)
        angle.params["C-C-H"] = dict(k=self.angle_k, t0=self.angle_theta0)
        angle.params["C-H-C"] = dict(k=self.angle_k, t0=self.angle_theta0)
        angle.params["H-C-C"] = dict(k=self.angle_k, t0=self.angle_theta0)
        angle.params["H-H-C"] = dict(k=self.angle_k, t0=self.angle_theta0)
        angle.params["C-H-H"] = dict(k=self.angle_k, t0=self.angle_theta0)
        angle.params["H-C-H"] = dict(k=self.angle_k, t0=self.angle_theta0)
        angle.params["H-H-H"] = dict(k=self.angle_k, t0=self.angle_theta0)
        angle.params["H-C-S"] = dict(k=self.angle_k, t0=self.angle_theta0)
        angle.params["C-S-H"] = dict(k=self.angle_k, t0=self.angle_theta0)
        angle.params["C-S-C"] = dict(k=self.angle_k, t0=self.angle_theta0)
        angle.params["S-C-H"] = dict(k=self.angle_k, t0=self.angle_theta0)
        angle.params["S-C-C"] = dict(k=self.angle_k, t0=self.angle_theta0)
        forces.append(angle)

        periodic_dihedral = hoomd.md.dihedral.Periodic()
        periodic_dihedral.params["H-C-C-H"] = dict(k=100.0, d=1, n=4, phi0=math.pi / 2)
        periodic_dihedral.params["C-C-C-H"] = dict(k=100.0, d=1, n=4, phi0=math.pi / 2)
        periodic_dihedral.params["C-C-C-C"] = dict(k=100.0, d=1, n=4, phi0=math.pi / 2)
        forces.append(periodic_dihedral)

        return forces

# %%
molecules = PolyEthylene(num_mols=1, lengths=8)
system = Pack(molecules=molecules, density=0.1)
ff = DPD_AA_FF(epsilon=1.0,A=5000,gamma=800,kT=1.0,r_cut=1.15,bond_k=30000,bond_r0=0.1,angle_k=400,angle_theta0=2.1,torsion_c0=30.334,torsion_c2=-30.334)
sim = Simulation.from_system(
    system=system,
    forcefield=ff.hoomd_forces,
    gsd_write_freq=100,
    log_write_freq=100
)
# Out:
# Initializing simulation state from a gsd.hoomd.Frame.
# /Users/stephaniemccallum/Desktop/cmelab/forks/flowerMD/flowermd/base/system.py:686: UserWarning: Units for density were not given, assuming units of g/cm**3.
#   warnings.warn(
# /Users/stephaniemccallum/miniforge3/envs/flowermd/lib/python3.12/site-packages/mbuild/compound.py:546: UserWarning: Some particle of <polyethylene_8mer 50 particles, 49 bonds, non-periodic, id: 10872068224> does not have a charge.They will not be accounted for during this calculation.
#   warn(
# /Users/stephaniemccallum/miniforge3/envs/flowermd/lib/python3.12/site-packages/gmso/external/convert_hoomd.py:1514: UserWarning: Neither base_units or auto_scale is provided, will infer base units from topology.
#   warnings.warn(
# /Users/stephaniemccallum/miniforge3/envs/flowermd/lib/python3.12/site-packages/gmso/external/convert_hoomd.py:737: UserWarning: Orthorhombic box detected
#   warnings.warn("Orthorhombic box detected")
# /Users/stephaniemccallum/miniforge3/envs/flowermd/lib/python3.12/site-packages/gmso/external/convert_hoomd.py:156: NotYetImplementedWarning: Only writing particle, bond, sangle, proper and improper dihedral information.Special pairs are not currently written to GSD files
#   warnings.warn(
# /Users/stephaniemccallum/miniforge3/envs/flowermd/lib/python3.12/site-packages/gmso/external/convert_hoomd.py:346: UserWarning: Shifting coordinates to [-L/2, L/2]
#   warnings.warn("Shifting coordinates to [-L/2, L/2]")
# /Users/stephaniemccallum/miniforge3/envs/flowermd/lib/python3.12/site-packages/gmso/external/convert_hoomd.py:549: UserWarning: 49 bonds detected
#   warnings.warn(f"{top.n_bonds} bonds detected")
# /Users/stephaniemccallum/miniforge3/envs/flowermd/lib/python3.12/site-packages/gmso/external/convert_hoomd.py:581: UserWarning: 2 unique bond types detected
#   warnings.warn(f"{len(unique_bond_types)} unique bond types detected")
# /Users/stephaniemccallum/miniforge3/envs/flowermd/lib/python3.12/site-packages/gmso/external/convert_hoomd.py:631: UserWarning: 96 angles detected
#   warnings.warn(f"{top.n_angles} angles detected")
# /Users/stephaniemccallum/miniforge3/envs/flowermd/lib/python3.12/site-packages/gmso/external/convert_hoomd.py:632: UserWarning: 3 unique angle types detected
#   warnings.warn(f"{len(unique_angle_types)} unique angle types detected")
# /Users/stephaniemccallum/miniforge3/envs/flowermd/lib/python3.12/site-packages/gmso/external/convert_hoomd.py:680: UserWarning: 135 dihedrals detected
#   warnings.warn(f"{top.n_dihedrals} dihedrals detected")
# /Users/stephaniemccallum/miniforge3/envs/flowermd/lib/python3.12/site-packages/gmso/external/convert_hoomd.py:681: UserWarning: 3 unique dihedral types detected
#   warnings.warn(f"{len(unique_dihedral_types)} unique dihedral types detected")
# /Users/stephaniemccallum/miniforge3/envs/flowermd/lib/python3.12/site-packages/gmso/external/convert_hoomd.py:728: UserWarning: 64 impropers detected
#   warnings.warn(f"{top.n_impropers} impropers detected")
# /Users/stephaniemccallum/miniforge3/envs/flowermd/lib/python3.12/site-packages/gmso/external/convert_hoomd.py:729: UserWarning: 3 unique dihedral types detected
#   warnings.warn(f"{len(unique_improper_types)} unique dihedral types detected")

# %%
sim.run_NVT(n_steps=10000,kT=1.0,tau_kt=0.01)
# Out:
# Step 90 of 10000; TPS: 2959.94; ETA: 0.1 minutes
# Step 190 of 10000; TPS: 4541.98; ETA: 0.0 minutes
# Step 290 of 10000; TPS: 5876.99; ETA: 0.0 minutes
# Step 390 of 10000; TPS: 7266.09; ETA: 0.0 minutes
# Step 490 of 10000; TPS: 8527.37; ETA: 0.0 minutes
# Step 590 of 10000; TPS: 9674.67; ETA: 0.0 minutes
# Step 690 of 10000; TPS: 10638.13; ETA: 0.0 minutes
# Step 790 of 10000; TPS: 11488.9; ETA: 0.0 minutes
# Step 890 of 10000; TPS: 12292.65; ETA: 0.0 minutes
# Step 990 of 10000; TPS: 13027.52; ETA: 0.0 minutes
# Step 1090 of 10000; TPS: 13757.24; ETA: 0.0 minutes
# Step 1190 of 10000; TPS: 14437.37; ETA: 0.0 minutes
# Step 5690 of 10000; TPS: 27339.47; ETA: 0.0 minutes
# Step 5790 of 10000; TPS: 27480.22; ETA: 0.0 minutes
# Step 5890 of 10000; TPS: 27618.09; ETA: 0.0 minutes
# Step 5990 of 10000; TPS: 27756.54; ETA: 0.0 minutes
# Step 6090 of 10000; TPS: 27890.36; ETA: 0.0 minutes
# Step 6190 of 10000; TPS: 28022.36; ETA: 0.0 minutes
# Step 6290 of 10000; TPS: 28149.85; ETA: 0.0 minutes
# Step 6390 of 10000; TPS: 28275.59; ETA: 0.0 minutes
# Step 6490 of 10000; TPS: 28398.65; ETA: 0.0 minutes
# Step 6590 of 10000; TPS: 28521.35; ETA: 0.0 minutes
# Step 6690 of 10000; TPS: 28640.54; ETA: 0.0 minutes
# Step 6790 of 10000; TPS: 28760.34; ETA: 0.0 minutes
# Step 6890 of 10000; TPS: 28874.12; ETA: 0.0 minutes
# Step 6990 of 10000; TPS: 28990.2; ETA: 0.0 minutes
# Step 7090 of 10000; TPS: 29102.94; ETA: 0.0 minutes
# Step 7190 of 10000; TPS: 29196.67; ETA: 0.0 minutes
# Step 7290 of 10000; TPS: 29284.16; ETA: 0.0 minutes
# Step 7390 of 10000; TPS: 29380.19; ETA: 0.0 minutes
# Step 7490 of 10000; TPS: 29474.38; ETA: 0.0 minutes
# Step 7590 of 10000; TPS: 29578.42; ETA: 0.0 minutes
# Step 7690 of 10000; TPS: 29680.23; ETA: 0.0 minutes
# Step 7790 of 10000; TPS: 29784.32; ETA: 0.0 minutes
# Step 7890 of 10000; TPS: 29875.16; ETA: 0.0 minutes
# Step 7990 of 10000; TPS: 29975.5; ETA: 0.0 minutes
# Step 8090 of 10000; TPS: 30074.35; ETA: 0.0 minutes
# Step 8190 of 10000; TPS: 30174.97; ETA: 0.0 minutes
# Step 8290 of 10000; TPS: 30267.63; ETA: 0.0 minutes
# Step 8390 of 10000; TPS: 30360.49; ETA: 0.0 minutes
# Step 8490 of 10000; TPS: 30452.7; ETA: 0.0 minutes
# Step 8590 of 10000; TPS: 30549.61; ETA: 0.0 minutes
# Step 8690 of 10000; TPS: 30642.61; ETA: 0.0 minutes
# Step 8790 of 10000; TPS: 30735.99; ETA: 0.0 minutes
# Step 8890 of 10000; TPS: 30826.74; ETA: 0.0 minutes
# Step 8990 of 10000; TPS: 30915.67; ETA: 0.0 minutes
# Step 9090 of 10000; TPS: 31004.21; ETA: 0.0 minutes
# Step 9190 of 10000; TPS: 31093.62; ETA: 0.0 minutes
# Step 9290 of 10000; TPS: 31179.94; ETA: 0.0 minutes
# Step 9390 of 10000; TPS: 31268.11; ETA: 0.0 minutes
# Step 9490 of 10000; TPS: 31349.0; ETA: 0.0 minutes
# Step 9590 of 10000; TPS: 31435.82; ETA: 0.0 minutes
# Step 9690 of 10000; TPS: 31518.14; ETA: 0.0 minutes
# Step 9790 of 10000; TPS: 31602.87; ETA: 0.0 minutes
# Step 9890 of 10000; TPS: 31685.11; ETA: 0.0 minutes
# Step 9990 of 10000; TPS: 31768.85; ETA: 0.0 minutes
