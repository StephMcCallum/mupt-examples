# %% [markdown]
# ### Notebook for initializing polymer systems using a DPD potential

# %% [markdown]
# Environment: conda install flowermd

# %%
import matplotlib
import numpy as np  
import gsd, gsd.hoomd 
import hoomd 
import time
import matplotlib_inline
import matplotlib.pyplot as plt
import freud
# %matplotlib inline
matplotlib.style.use("ggplot")
matplotlib_inline.backend_inline.set_matplotlib_formats("svg")

# %% [markdown]
# ## Generate CG trajectory with random walk + DPD workflow

# %%
def initialize_snapshot_rand_walk(num_pol, num_mon, density=0.85, bond_length=1.0, buffer=0.1):
    '''
    Create a HOOMD snapshot of a cubic box with the number density given by input parameters.
    '''    
    N = num_pol * num_mon
    L = np.cbrt(N / density)  # Calculate box size based on density
    positions = np.zeros((N, 3))
    for i in range(num_pol):
        start = i * num_mon
        positions[start] = np.random.uniform(low=(-((L/2)-0.5)),high=((L/2)-0.5),size=3)
        for j in range(num_mon - 1):
            delta = np.random.uniform(low=(-bond_length/2),high=(bond_length/2),size=3)
            delta /= np.linalg.norm(delta)*bond_length
            positions[start+j+1] = positions[start+j] + delta
    positions = pbc(positions,[L,L,L])
    bonds = []
    for i in range(num_pol):
        start = i * num_mon
        for j in range(num_mon - 1):
            bonds.append([start + j, start + j + 1])
    angles = []
    for i in range(num_pol):
        start = i * num_mon
        for j in range(num_mon - 2):
            angles.append([start + j, start + j + 1,start + j + 2])
    dihedrals = []
    for i in range(num_pol):
        start = i * num_mon
        for j in range(num_mon - 3):
            dihedrals.append([start + j, start + j + 1,start + j + 2,start + j + 3])
    bonds = np.array(bonds)
    angles = np.array(angles)
    dihedrals = np.array(dihedrals)
    frame = gsd.hoomd.Frame()
    frame.particles.types = ['A']
    frame.particles.N = N
    frame.particles.position = positions
    frame.bonds.N = len(bonds)
    frame.bonds.group = bonds
    frame.bonds.types = ['b']
    frame.angles.N = (num_mon - 2)*num_pol
    frame.angles.types = ["A-A-A"]
    frame.angles.group = angles
    frame.dihedrals.N = (num_mon - 3)*num_pol
    frame.dihedrals.types = ["A-A-A-A"]
    frame.dihedrals.group = dihedrals
    frame.configuration.box = [L, L, L, 0, 0, 0]
    return frame

def pbc(d,box):
    for i in range(3):
        a = d[:,i]
        pos_max = np.max(a)
        pos_min = np.min(a)
        while pos_max > box[i]/2 or pos_min < -box[i]/2:
            a[a < -box[i]/2] += box[i]
            a[a >  box[i]/2] -= box[i]
            pos_max = np.max(a)
            pos_min = np.min(a)
    return d

def check_bond_length_equilibration(snap,num_mon,num_pol,max_bond_length=1.1,min_bond_length=0.9): #todo
    frame_ds = []
    for j in range(num_pol):
        idx = j*num_mon
        d1 = snap.particles.position[idx:idx+num_mon-1] - snap.particles.position[idx+1:idx+num_mon]
        bond_l = np.linalg.norm(pbc(d1,snap.configuration.box),axis=1)
        frame_ds.append(bond_l)
    max_frame_bond_l = np.max(np.array(frame_ds))
    min_frame_bond_l = np.min(np.array(frame_ds))
    print("max: ",max_frame_bond_l," min: ",min_frame_bond_l)
    if max_frame_bond_l <= max_bond_length and min_frame_bond_l >= min_bond_length:
        print("Bond length equillibrated.")
        return True
    if max_frame_bond_l > max_bond_length or min_frame_bond_l < min_bond_length:
        return False

def check_inter_particle_distance(snap,minimum_distance=0.95):
    '''
    Check particle separations.
    
    '''
    positions = snap.particles.position
    box = snap.configuration.box
    aq = freud.locality.AABBQuery(box,positions)
    aq_query = aq.query(
        query_points=positions,
        query_args=dict(r_min=0.0, r_max=minimum_distance, exclude_ii=True),
    )
    nlist = aq_query.toNeighborList()
    if len(nlist)==0:
        print("Inter-particle separation reached.")
        return True
    else:
        return False
        
def run_one(A=1000,gamma=1000,k=1000,num_pol=100,num_mon=10,kT=1.0,r_cut = 1.15,bond_l=1.0,dt=0.001,density=0.01,particle_spacing = 1.1
):
    print(num_pol*num_mon)
    print(f"\nRunning with A={A}, gamma={gamma}, k={k}, "
          f"num_pol={num_pol}, num_mon={num_mon}")
    start_time = time.perf_counter()
    frame = initialize_snapshot_rand_walk(num_pol, num_mon, density=density)
    build_stop = time.perf_counter()
    print("Total build time: ", build_stop-start_time)
    harmonic = hoomd.md.bond.Harmonic()
    harmonic.params["b"] = dict(r0=bond_l, k=k)
    integrator = hoomd.md.Integrator(dt=dt)
    integrator.forces.append(harmonic)
    simulation = hoomd.Simulation(device=hoomd.device.auto_select(), seed=np.random.randint(65535))# TODO seed
    simulation.operations.integrator = integrator 
    simulation.create_state_from_snapshot(frame)
    const_vol = hoomd.md.methods.ConstantVolume(filter=hoomd.filter.All())
    integrator.methods.append(const_vol)
    nlist = hoomd.md.nlist.Cell(buffer=0.4)
    simulation.operations.nlist = nlist
    DPD = hoomd.md.pair.DPD(nlist, default_r_cut=r_cut, kT=kT)
    DPD.params[('A', 'A')] = dict(A=A, gamma=gamma)
    integrator.forces.append(DPD)

    gsd_out = hoomd.write.GSD(
        trigger=hoomd.trigger.Periodic(100),
        mode='wb',
        dynamic=['property', 'momentum'],
        filename='bead-spring-dpd-single-chain.gsd')

    simulation.operations.writers.append(gsd_out)
    
    simulation.run(0)
    simulation.run(100)
    snap=simulation.state.get_snapshot()
    N = num_pol*num_mon
    time_factor = N/90000

    while not check_bond_length_equilibration(snap,num_mon, num_pol,max_bond_length=particle_spacing): #TODO - work with snapshot instead of gsd?
        check_time = time.perf_counter()
        if (check_time-start_time) > 120:
            return num_pol*num_mon, 0
        simulation.run(1000)
        snap=simulation.state.get_snapshot()

    while not check_inter_particle_distance(snap,minimum_distance=0.97):
        check_time = time.perf_counter()
        if (check_time-start_time) > 120:
            return num_pol*num_mon, 0
        simulation.run(1000)
        snap=simulation.state.get_snapshot()
        
    end_time = time.perf_counter()
    gsd_out.flush()
    return num_pol*num_mon, end_time - start_time
    
N,s = run_one(A=5000,gamma=800,k=25000,num_pol=1,num_mon=5) #A=1000 seems fast, cranking up gamma to 800 speeds up, cranking up k more does too,
#no difference between k=10k and 20k
#OK, with these parameters, we're finishing in under 100 steps
print(f"Finished in time = {s:.2f}s")
# Out:
# 5
#
# Running with A=5000, gamma=800, k=25000, num_pol=1, num_mon=5
# Total build time:  0.00019975000759586692
# max:  1.0041290342390763  min:  0.9935682553486876
# Bond length equillibrated.
# Inter-particle separation reached.
# Finished in time = 0.18s

# %% [markdown]
# ## Isolate last frame from relaxed trajectory

# %%
traj = gsd.hoomd.open('bead-spring-dpd-single-chain.gsd','r')
last_frame = traj[-1]
with gsd.hoomd.open('last-dpd-frame.gsd','w') as new_traj:
    new_traj.append(last_frame)

# %% [markdown]
# ## export last frame to grits fine-graining notebook

# %% [markdown]
# ## import fine-grained structure

# %%
NonbondedForce_scale = {'coulomb14scale':0.5, 'lj14scale':0.5}
nonbondedforce = {
		'hs':{'charge':0.155, 'sigma':0.0, 'epsilon':0.0},
        'ca':{'charge':-0.155, 'sigma':0.355, 'epsilon':0.29288},
        's':{'charge':-0.335, 'sigma':0.36, 'epsilon':1.48532},
        'ha':{'charge':0.155, 'sigma':0.242, 'epsilon':0.12552},
        'sh':{'charge':-0.335, 'sigma':0.36, 'epsilon':1.7782}
}

# %%
from flowermd.base import Pack,Lattice, Simulation,BaseHOOMDForcefield,Polymer, forcefield
from flowermd.base.system import System
from flowermd.library import forcefields
# Out:
# /Users/stephaniemccallum/miniforge3/envs/mupt-examples/lib/python3.12/site-packages/gmso/core/element.py:10: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import resource_filename

# %%
class DPD_AA_FF(BaseHOOMDForcefield):
    def __init__(
        self,
        epsilon,
        A,
        gamma,
        kT,
        r_cut
    ):
        self.epsilon = epsilon
        self.gamma = gamma
        self.A = A
        self.kT = kT
        self.r_cut = r_cut
        hoomd_forces = self._create_forcefield()
        super(DPD_FF, self).__init__(hoomd_forces)

    def _create_forcefield(self):
        forces = []
        #opls = forcefields.FF_from_file('pps_opls.xml')
        #print(opls)
        #forces.append(opls.hoomd_forces)
        #use non-bonded epsilons and sigmas to scale A and gamma for each atom type
        #use bonds, angles, and dihedrals as is
        # add bonds, angles and dihedrals to the hoomd simulation
        nlist = hoomd.md.nlist.Cell(buffer=0.40, exclusions=["body"])
        dpd = hoomd.md.pair.DPD(nlist=nlist,kT=self.kT,default_r_cut=self.r_cut)
        dpd.params[("H","H")] = dict(A=0,gamma=0.1)
        dpd.params[("H","H")].r_cut = self.r_cut
        dpd.params[("H","C")] = dict(A=0,gamma=0.1)
        dpd.params[("H","C")].r_cut = self.r_cut
        dpd.params[("H","S")] = dict(A=0,gamma=0.1)
        dpd.params[("H","S")].r_cut = self.r_cut
        cc_factor = nonbondedforce['ca']['epsilon']/nonbondedforce['sh']['epsilon']
        dpd.params[("C","C")] = dict(A=self.A*cc_factor,gamma=self.gamma*cc_factor)
        dpd.params[("C","C")].r_cut = self.r_cut
        cs_factor = nonbondedforce['s']['epsilon']/nonbondedforce['sh']['epsilon']
        dpd.params[("C","S")] = dict(A=self.A*cs_factor,gamma=self.gamma*cs_factor)
        dpd.params[("C","S")].r_cut = self.r_cut
        ss_factor = nonbondedforce['s']['epsilon']/nonbondedforce['sh']['epsilon']
        dpd.params[("S","S")] = dict(A=self.A*ss_factor,gamma=self.gamma*ss_factor)
        dpd.params[("S","S")].r_cut = self.r_cut
        forces.append(dpd)
        return forces

# %%
from flowermd.library import OPLS_AA_PPS

# %%
simulation = hoomd.Simulation(device=hoomd.device.auto_select(), seed=np.random.randint(65535))# TODO seed
simulation.operations.integrator = integrator 
simulation.create_state_from_snapshot(frame)

# %%
non_bonded_ff = DPD_AA_FF(epsilon=1.0,A=5000,gamma=800,kT=1.0,r_cut=1.15)

opls_ff = forcefields.FF_from_file('pps_opls.xml')
sim = Simulation(
    initial_state='pps-from-dpd-single-chain.gsd',
    forcefield=non_bonded_ff.hoomd_forces,
    dt=0.001,
    gsd_write_freq=int(100),
    gsd_file_name='trajectory.gsd',
    log_write_freq=int(100),
    log_file_name='log.txt')

sim.save_restart_gsd()
sim.run_NVT(n_steps=1e4, kT=1.0, tau_kt=10*sim.dt)
sim.flush_writers()
# Out:
# Initializing simulation state from a GSD file.
# Step 100 of 10000; TPS: 606.97; ETA: 0.3 minutes
# Step 200 of 10000; TPS: 1209.82; ETA: 0.1 minutes
# Step 300 of 10000; TPS: 1810.23; ETA: 0.1 minutes
# Step 400 of 10000; TPS: 2408.1; ETA: 0.1 minutes
# Step 500 of 10000; TPS: 3003.31; ETA: 0.1 minutes
# Step 600 of 10000; TPS: 3595.83; ETA: 0.0 minutes
# Step 700 of 10000; TPS: 4185.68; ETA: 0.0 minutes
# Step 800 of 10000; TPS: 4773.04; ETA: 0.0 minutes
# Step 900 of 10000; TPS: 5357.88; ETA: 0.0 minutes
# Step 1000 of 10000; TPS: 5939.83; ETA: 0.0 minutes
# Step 1100 of 10000; TPS: 6519.75; ETA: 0.0 minutes
# Step 1200 of 10000; TPS: 7097.36; ETA: 0.0 minutes
# Step 1300 of 10000; TPS: 7672.65; ETA: 0.0 minutes
# Step 1400 of 10000; TPS: 8211.0; ETA: 0.0 minutes
# Step 1500 of 10000; TPS: 8779.48; ETA: 0.0 minutes
# Step 1600 of 10000; TPS: 9345.58; ETA: 0.0 minutes
# Step 1700 of 10000; TPS: 9909.47; ETA: 0.0 minutes
# Step 1800 of 10000; TPS: 10471.57; ETA: 0.0 minutes
# Step 1900 of 10000; TPS: 11031.12; ETA: 0.0 minutes
# Step 2000 of 10000; TPS: 11588.76; ETA: 0.0 minutes
# Step 2100 of 10000; TPS: 12142.73; ETA: 0.0 minutes
# Step 2200 of 10000; TPS: 12696.07; ETA: 0.0 minutes
# Step 2300 of 10000; TPS: 13247.09; ETA: 0.0 minutes
# Step 2400 of 10000; TPS: 13797.07; ETA: 0.0 minutes
# Step 2500 of 10000; TPS: 14344.4; ETA: 0.0 minutes
# Step 2600 of 10000; TPS: 14890.16; ETA: 0.0 minutes
# Step 2700 of 10000; TPS: 15433.86; ETA: 0.0 minutes
# Step 2800 of 10000; TPS: 15975.9; ETA: 0.0 minutes
# Step 2900 of 10000; TPS: 16515.46; ETA: 0.0 minutes
# Step 3000 of 10000; TPS: 17053.98; ETA: 0.0 minutes
# Step 3100 of 10000; TPS: 17590.25; ETA: 0.0 minutes
# Step 3200 of 10000; TPS: 18124.77; ETA: 0.0 minutes
# Step 3300 of 10000; TPS: 18656.72; ETA: 0.0 minutes
# Step 3400 of 10000; TPS: 19187.14; ETA: 0.0 minutes
# Step 3500 of 10000; TPS: 19715.87; ETA: 0.0 minutes
# Step 3600 of 10000; TPS: 20241.66; ETA: 0.0 minutes
# Step 3700 of 10000; TPS: 20764.12; ETA: 0.0 minutes
# Step 3800 of 10000; TPS: 21287.92; ETA: 0.0 minutes
# Step 3900 of 10000; TPS: 21808.79; ETA: 0.0 minutes
# Step 4000 of 10000; TPS: 22328.53; ETA: 0.0 minutes
# Step 4100 of 10000; TPS: 22846.57; ETA: 0.0 minutes
# Step 4200 of 10000; TPS: 23362.8; ETA: 0.0 minutes
# Step 4300 of 10000; TPS: 23876.69; ETA: 0.0 minutes
# Step 4400 of 10000; TPS: 24389.43; ETA: 0.0 minutes
# Step 4500 of 10000; TPS: 24900.12; ETA: 0.0 minutes
# Step 4600 of 10000; TPS: 25408.33; ETA: 0.0 minutes
# Step 4700 of 10000; TPS: 25915.16; ETA: 0.0 minutes
# Step 4800 of 10000; TPS: 26420.95; ETA: 0.0 minutes
# Step 4900 of 10000; TPS: 26924.7; ETA: 0.0 minutes
# Step 5000 of 10000; TPS: 27427.17; ETA: 0.0 minutes
# Step 5100 of 10000; TPS: 27926.84; ETA: 0.0 minutes
# Step 5200 of 10000; TPS: 28425.09; ETA: 0.0 minutes
# Step 5300 of 10000; TPS: 28921.76; ETA: 0.0 minutes
# Step 5400 of 10000; TPS: 29417.53; ETA: 0.0 minutes
# Step 5500 of 10000; TPS: 29910.0; ETA: 0.0 minutes
# Step 5600 of 10000; TPS: 30402.23; ETA: 0.0 minutes
# Step 5700 of 10000; TPS: 30892.3; ETA: 0.0 minutes
# Step 5800 of 10000; TPS: 31351.52; ETA: 0.0 minutes
# Step 5900 of 10000; TPS: 31800.27; ETA: 0.0 minutes
# Step 6000 of 10000; TPS: 32277.67; ETA: 0.0 minutes
# Step 6100 of 10000; TPS: 32756.78; ETA: 0.0 minutes
# Step 6200 of 10000; TPS: 33236.13; ETA: 0.0 minutes
# Step 6300 of 10000; TPS: 33714.0; ETA: 0.0 minutes
# Step 6400 of 10000; TPS: 34191.87; ETA: 0.0 minutes
# Step 6500 of 10000; TPS: 34667.59; ETA: 0.0 minutes
# Step 6600 of 10000; TPS: 35143.4; ETA: 0.0 minutes
# Step 6700 of 10000; TPS: 35615.19; ETA: 0.0 minutes
# Step 6800 of 10000; TPS: 36085.37; ETA: 0.0 minutes
# Step 6900 of 10000; TPS: 36554.94; ETA: 0.0 minutes
# Step 7000 of 10000; TPS: 37022.93; ETA: 0.0 minutes
# Step 7100 of 10000; TPS: 37490.76; ETA: 0.0 minutes
# Step 7200 of 10000; TPS: 37957.67; ETA: 0.0 minutes
# Step 7300 of 10000; TPS: 38423.07; ETA: 0.0 minutes
# Step 7400 of 10000; TPS: 38887.4; ETA: 0.0 minutes
# Step 7500 of 10000; TPS: 39350.04; ETA: 0.0 minutes
# Step 7600 of 10000; TPS: 39811.0; ETA: 0.0 minutes
# Step 7700 of 10000; TPS: 40270.28; ETA: 0.0 minutes
# Step 7800 of 10000; TPS: 40728.52; ETA: 0.0 minutes
# Step 7900 of 10000; TPS: 41184.87; ETA: 0.0 minutes
# Step 8000 of 10000; TPS: 41640.21; ETA: 0.0 minutes
# Step 8100 of 10000; TPS: 42078.14; ETA: 0.0 minutes
# Step 8200 of 10000; TPS: 42492.77; ETA: 0.0 minutes
# Step 8300 of 10000; TPS: 42939.55; ETA: 0.0 minutes
# Step 8400 of 10000; TPS: 43389.1; ETA: 0.0 minutes
# Step 8500 of 10000; TPS: 43836.58; ETA: 0.0 minutes
# Step 8600 of 10000; TPS: 44283.56; ETA: 0.0 minutes
# Step 8700 of 10000; TPS: 44727.78; ETA: 0.0 minutes
# Step 8800 of 10000; TPS: 45171.99; ETA: 0.0 minutes
# Step 8900 of 10000; TPS: 45614.36; ETA: 0.0 minutes
# Step 9000 of 10000; TPS: 46055.36; ETA: 0.0 minutes
# Step 9100 of 10000; TPS: 46495.23; ETA: 0.0 minutes
# Step 9200 of 10000; TPS: 46934.7; ETA: 0.0 minutes
# Step 9300 of 10000; TPS: 47369.95; ETA: 0.0 minutes
# Step 9400 of 10000; TPS: 47806.25; ETA: 0.0 minutes
# Step 9500 of 10000; TPS: 48241.23; ETA: 0.0 minutes
# Step 9600 of 10000; TPS: 48674.14; ETA: 0.0 minutes
# Step 9700 of 10000; TPS: 49106.46; ETA: 0.0 minutes
# Step 9800 of 10000; TPS: 49537.23; ETA: 0.0 minutes
# Step 9900 of 10000; TPS: 49965.93; ETA: 0.0 minutes

# %%
opls = forcefields.FF_from_file('pps_opls.xml')

# %%
opls.gmso_ff
# Out:
# <ForceField OPLS-AA,
#  5 AtomTypes,
#  6 BondTypes,
#  8 AngleTypes,
#  12 DihedralTypes,
#  0 ImproperType,
#  0 PairPotentialType,
#  id: 6428667600>

# %%
opls.gmso_ff.angle_types
# Out:
# {'CA~S~CA': <AngleType HarmonicAnglePotential,
#   expression: 0.5*k*(theta - theta_eq)**2,
#   id: 11214305984,
#   parameters: {'k': unyt_quantity(627.6, 'kJ/(mol*rad**2)'), 'theta_eq': unyt_quantity(1.805, 'rad')},
#  member types: None>,
#  'CA~SH~HS': <AngleType HarmonicAnglePotential,
#   expression: 0.5*k*(theta - theta_eq)**2,
#   id: 11214305744,
#   parameters: {'k': unyt_quantity(418.4, 'kJ/(mol*rad**2)'), 'theta_eq': unyt_quantity(1.67551608, 'rad')},
#  member types: None>,
#  'CA~CA~S': <AngleType HarmonicAnglePotential,
#   expression: 0.5*k*(theta - theta_eq)**2,
#   id: 11213604336,
#   parameters: {'k': unyt_quantity(711.28, 'kJ/(mol*rad**2)'), 'theta_eq': unyt_quantity(2.08392313, 'rad')},
#  member types: None>,
#  'CA~CA~CA': <AngleType HarmonicAnglePotential,
#   expression: 0.5*k*(theta - theta_eq)**2,
#   id: 11213609616,
#   parameters: {'k': unyt_quantity(527.184, 'kJ/(mol*rad**2)'), 'theta_eq': unyt_quantity(2.0943951, 'rad')},
#  member types: None>,
#  'CA~CA~SH': <AngleType HarmonicAnglePotential,
#   expression: 0.5*k*(theta - theta_eq)**2,
#   id: 11213610336,
#   parameters: {'k': unyt_quantity(585.76, 'kJ/(mol*rad**2)'), 'theta_eq': unyt_quantity(2.0943951, 'rad')},
#  member types: None>,
#  'SH~CA~CA': <AngleType HarmonicAnglePotential,
#   expression: 0.5*k*(theta - theta_eq)**2,
#   id: 11213605776,
#   parameters: {'k': unyt_quantity(585.76, 'kJ/(mol*rad**2)'), 'theta_eq': unyt_quantity(2.0943951, 'rad')},
#  member types: None>,
#  'CA~CA~HA': <AngleType HarmonicAnglePotential,
#   expression: 0.5*k*(theta - theta_eq)**2,
#   id: 11213617056,
#   parameters: {'k': unyt_quantity(292.88, 'kJ/(mol*rad**2)'), 'theta_eq': unyt_quantity(2.0943951, 'rad')},
#  member types: None>,
#  'S~CA~CA': <AngleType HarmonicAnglePotential,
#   expression: 0.5*k*(theta - theta_eq)**2,
#   id: 11214441200,
#   parameters: {'k': unyt_quantity(711.28, 'kJ/(mol*rad**2)'), 'theta_eq': unyt_quantity(2.08392313, 'rad')},
#  member types: None>}

# %%
opls.gmso_ff.atom_types
# Out:
# {'hs': <AtomType hs,
#   expression: 4*epsilon*(-sigma**6/r**6 + sigma**12/r**12),
#   id: 11214438480,
#   atomclass: HS>,
#  'ca': <AtomType ca,
#   expression: 4*epsilon*(-sigma**6/r**6 + sigma**12/r**12),
#   id: 11214440480,
#   atomclass: CA>,
#  's': <AtomType s,
#   expression: 4*epsilon*(-sigma**6/r**6 + sigma**12/r**12),
#   id: 11214445440,
#   atomclass: S>,
#  'ha': <AtomType ha,
#   expression: 4*epsilon*(-sigma**6/r**6 + sigma**12/r**12),
#   id: 11214442320,
#   atomclass: HA>,
#  'sh': <AtomType sh,
#   expression: 4*epsilon*(-sigma**6/r**6 + sigma**12/r**12),
#   id: 11214444400,
#   atomclass: SH>}

# %%
opls.gmso_ff.pairpotential_types
# Out:
# {}

# %%
opls.gmso_ff.get_potential
# Out:
# <bound method ForceField.get_potential of <ForceField OPLS-AA,
#  5 AtomTypes,
#  6 BondTypes,
#  8 AngleTypes,
#  12 DihedralTypes,
#  0 ImproperType,
#  0 PairPotentialType,
#  id: 6428667600>>

# %%
opls.gmso_ff.to_xml('pps-opls-dpd.xml')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[80], line 1
# ----> 1 opls.get_parameters(group='PairPotentialType',key='hs')
#
# File ~/miniforge3/envs/mupt-examples/lib/python3.12/site-packages/foyer/forcefield.py:1338, in Forcefield.get_parameters(self, group, key, keys_are_atom_classes)
#    1327 param_extractors = {
#    1328     "atoms": self._extract_non_bonded_params,
#    1329     "harmonic_bonds": self._extract_harmonic_bond_params,
#    (...)   1334     "rb_impropers": self._extract_rb_improper_params,
#    1335 }
#    1337 if group not in param_extractors:
# -> 1338     raise ValueError(f"Cannot extract parameters for {group}")
#    1340 key = (
#    1341     [key]
#    1342     if isinstance(key, str) or not isinstance(key, Iterable)
#    1343     else key
#    1344 )
#    1346 validate_type(key, str)
#
# ValueError: Cannot extract parameters for pairpotentialtype

# %%
traj = gsd.hoomd.open('pps-from-dpd-single-chain.gsd','r')

# %%
frame = traj[-1]

# %%
frame.angles.typeid
# Out:
# array([], dtype=uint32)

# %%
frame.bonds.types
# Out:
# ['C-C', 'C-H', 'C-S']

# %%
frame.angles.N
# Out:
# 0

# %%
frame.dihedrals.N
# Out:
# 0

# %%
frame.dihedrals.types
# Out:
# []

# %%
angles = np.array(angles)
dihedrals = np.array(dihedrals)
frame = gsd.hoomd.Frame()
frame.particles.types = ['A']
frame.particles.N = N
frame.particles.position = positions
frame.bonds.N = len(bonds)
frame.bonds.group = bonds
frame.bonds.types = ['b']
frame.angles.N = (num_mon - 2)*num_pol
frame.angles.types = ["A-A-A"]
frame.angles.group = angles
frame.dihedrals.N = (num_mon - 3)*num_pol
frame.dihedrals.types = ["A-A-A-A"]
frame.dihedrals.group = dihedrals
frame.configuration.box = [L, L, L, 0, 0, 0]
build_stop = time.perf_counter()
print("Total build time: ", build_stop-start_time)
harmonic = hoomd.md.bond.Harmonic()
harmonic.params["b"] = dict(r0=bond_l, k=k)
integrator = hoomd.md.Integrator(dt=dt)
integrator.forces.append(harmonic)
simulation = hoomd.Simulation(device=hoomd.device.auto_select(), seed=np.random.randint(65535))# TODO seed
simulation.operations.integrator = integrator 
simulation.create_state_from_snapshot(frame)
const_vol = hoomd.md.methods.ConstantVolume(filter=hoomd.filter.All())
integrator.methods.append(const_vol)
nlist = hoomd.md.nlist.Cell(buffer=0.4)
simulation.operations.nlist = nlist
DPD = hoomd.md.pair.DPD(nlist, default_r_cut=r_cut, kT=kT)
DPD.params[('A', 'A')] = dict(A=A, gamma=gamma)
integrator.forces.append(DPD)

gsd_out = hoomd.write.GSD(
    trigger=hoomd.trigger.Periodic(100),
    mode='wb',
    dynamic=['property', 'momentum'],
    filename='bead-spring-dpd-single-chain.gsd')

simulation.operations.writers.append(gsd_out)

simulation.run(0)
