# %% [markdown]
# ### Notebook for initializing polymer systems using a DPD potential

# %% [markdown]
# Environment: conda install flowermd

# %%
import matplotlib
import numpy as np  
import gsd, gsd.hoomd 
import hoomd 
import time
import matplotlib_inline
import matplotlib.pyplot as plt
import freud
# %matplotlib inline
matplotlib.style.use("ggplot")
matplotlib_inline.backend_inline.set_matplotlib_formats("svg")

# %% [markdown]
# ## Generate CG trajectory with random walk + DPD workflow

# %%
def initialize_snapshot_rand_walk(num_pol, num_mon, density=0.85, bond_length=1.0, buffer=0.1):
    '''
    Create a HOOMD snapshot of a cubic box with the number density given by input parameters.
    '''    
    N = num_pol * num_mon
    L = np.cbrt(N / density)  # Calculate box size based on density
    positions = np.zeros((N, 3))
    for i in range(num_pol):
        start = i * num_mon
        positions[start] = np.random.uniform(low=(-((L/2)-0.5)),high=((L/2)-0.5),size=3)
        for j in range(num_mon - 1):
            delta = np.random.uniform(low=(-bond_length/2),high=(bond_length/2),size=3)
            delta /= np.linalg.norm(delta)*bond_length
            positions[start+j+1] = positions[start+j] + delta
    positions = pbc(positions,[L,L,L])
    bonds = []
    for i in range(num_pol):
        start = i * num_mon
        for j in range(num_mon - 1):
            bonds.append([start + j, start + j + 1])
    angles = []
    for i in range(num_pol):
        start = i * num_mon
        for j in range(num_mon - 2):
            angles.append([start + j, start + j + 1,start + j + 2])
    dihedrals = []
    for i in range(num_pol):
        start = i * num_mon
        for j in range(num_mon - 3):
            dihedrals.append([start + j, start + j + 1,start + j + 2,start + j + 3])
    bonds = np.array(bonds)
    angles = np.array(angles)
    dihedrals = np.array(dihedrals)
    frame = gsd.hoomd.Frame()
    frame.particles.types = ['A']
    frame.particles.N = N
    frame.particles.position = positions
    frame.bonds.N = len(bonds)
    frame.bonds.group = bonds
    frame.bonds.types = ['b']
    frame.angles.N = (num_mon - 2)*num_pol
    frame.angles.types = ["A-A-A"]
    frame.angles.group = angles
    frame.dihedrals.N = (num_mon - 3)*num_pol
    frame.dihedrals.types = ["A-A-A-A"]
    frame.dihedrals.group = dihedrals
    frame.configuration.box = [L, L, L, 0, 0, 0]
    return frame

def pbc(d,box):
    for i in range(3):
        a = d[:,i]
        pos_max = np.max(a)
        pos_min = np.min(a)
        while pos_max > box[i]/2 or pos_min < -box[i]/2:
            a[a < -box[i]/2] += box[i]
            a[a >  box[i]/2] -= box[i]
            pos_max = np.max(a)
            pos_min = np.min(a)
    return d

def check_bond_length_equilibration(snap,num_mon,num_pol,max_bond_length=1.1,min_bond_length=0.9): #todo
    frame_ds = []
    for j in range(num_pol):
        idx = j*num_mon
        d1 = snap.particles.position[idx:idx+num_mon-1] - snap.particles.position[idx+1:idx+num_mon]
        bond_l = np.linalg.norm(pbc(d1,snap.configuration.box),axis=1)
        frame_ds.append(bond_l)
    max_frame_bond_l = np.max(np.array(frame_ds))
    min_frame_bond_l = np.min(np.array(frame_ds))
    print("max: ",max_frame_bond_l," min: ",min_frame_bond_l)
    if max_frame_bond_l <= max_bond_length and min_frame_bond_l >= min_bond_length:
        print("Bond length equillibrated.")
        return True
    if max_frame_bond_l > max_bond_length or min_frame_bond_l < min_bond_length:
        return False

def check_inter_particle_distance(snap,minimum_distance=0.95):
    '''
    Check particle separations.
    
    '''
    positions = snap.particles.position
    box = snap.configuration.box
    aq = freud.locality.AABBQuery(box,positions)
    aq_query = aq.query(
        query_points=positions,
        query_args=dict(r_min=0.0, r_max=minimum_distance, exclude_ii=True),
    )
    nlist = aq_query.toNeighborList()
    if len(nlist)==0:
        print("Inter-particle separation reached.")
        return True
    else:
        return False
        
def run_one(A=1000,gamma=1000,k=1000,num_pol=100,num_mon=10,kT=1.0,r_cut = 1.15,bond_l=1.0,dt=0.001,density=0.01,particle_spacing = 1.1
):
    print(num_pol*num_mon)
    print(f"\nRunning with A={A}, gamma={gamma}, k={k}, "
          f"num_pol={num_pol}, num_mon={num_mon}")
    start_time = time.perf_counter()
    frame = initialize_snapshot_rand_walk(num_pol, num_mon, density=density)
    build_stop = time.perf_counter()
    print("Total build time: ", build_stop-start_time)
    harmonic = hoomd.md.bond.Harmonic()
    harmonic.params["b"] = dict(r0=bond_l, k=k)
    integrator = hoomd.md.Integrator(dt=dt)
    integrator.forces.append(harmonic)
    simulation = hoomd.Simulation(device=hoomd.device.auto_select(), seed=np.random.randint(65535))# TODO seed
    simulation.operations.integrator = integrator 
    simulation.create_state_from_snapshot(frame)
    const_vol = hoomd.md.methods.ConstantVolume(filter=hoomd.filter.All())
    integrator.methods.append(const_vol)
    nlist = hoomd.md.nlist.Cell(buffer=0.4)
    simulation.operations.nlist = nlist
    DPD = hoomd.md.pair.DPD(nlist, default_r_cut=r_cut, kT=kT)
    DPD.params[('A', 'A')] = dict(A=A, gamma=gamma)
    integrator.forces.append(DPD)

    gsd_out = hoomd.write.GSD(
        trigger=hoomd.trigger.Periodic(100),
        mode='wb',
        dynamic=['property', 'momentum'],
        filename='bead-spring-dpd-single-chain.gsd')

    simulation.operations.writers.append(gsd_out)
    
    simulation.run(0)
    simulation.run(100)
    snap=simulation.state.get_snapshot()
    N = num_pol*num_mon
    time_factor = N/90000

    while not check_bond_length_equilibration(snap,num_mon, num_pol,max_bond_length=particle_spacing): #TODO - work with snapshot instead of gsd?
        check_time = time.perf_counter()
        if (check_time-start_time) > 120:
            return num_pol*num_mon, 0
        simulation.run(1000)
        snap=simulation.state.get_snapshot()

    while not check_inter_particle_distance(snap,minimum_distance=0.97):
        check_time = time.perf_counter()
        if (check_time-start_time) > 120:
            return num_pol*num_mon, 0
        simulation.run(1000)
        snap=simulation.state.get_snapshot()
        
    end_time = time.perf_counter()
    gsd_out.flush()
    return num_pol*num_mon, end_time - start_time
    
N,s = run_one(A=5000,gamma=800,k=25000,num_pol=1,num_mon=5) #A=1000 seems fast, cranking up gamma to 800 speeds up, cranking up k more does too,
#no difference between k=10k and 20k
#OK, with these parameters, we're finishing in under 100 steps
print(f"Finished in time = {s:.2f}s")
# Out:
# 5
#
# Running with A=5000, gamma=800, k=25000, num_pol=1, num_mon=5
# Total build time:  0.001357375003863126
# max:  1.0088511931821538  min:  0.9978266227074186
# Bond length equillibrated.
# Inter-particle separation reached.
# Finished in time = 0.19s

# %% [markdown]
# ## Isolate last frame from relaxed trajectory

# %%
traj = gsd.hoomd.open('bead-spring-dpd-single-chain.gsd','r')
last_frame = traj[-1]
with gsd.hoomd.open('last-dpd-frame.gsd','w') as new_traj:
    new_traj.append(last_frame)

# %% [markdown]
# ## export last frame to grits fine-graining notebook

# %% [markdown]
# ## import fine-grained structure

# %%
NonbondedForce_scale = {'coulomb14scale':0.5, 'lj14scale':0.5}
nonbondedforce = {
		'hs':{'charge':0.155, 'sigma':0.0, 'epsilon':0.0},
        'ca':{'charge':-0.155, 'sigma':0.355, 'epsilon':0.29288},
        's':{'charge':-0.335, 'sigma':0.36, 'epsilon':1.48532},
        'ha':{'charge':0.155, 'sigma':0.242, 'epsilon':0.12552},
        'sh':{'charge':-0.335, 'sigma':0.36, 'epsilon':1.7782}
}

# %%
from flowermd.base import Pack,Lattice, Simulation,BaseHOOMDForcefield,Polymer, forcefield
from flowermd.base.system import System
from flowermd.library import forcefields
# Out:
# /Users/stephaniemccallum/miniforge3/envs/flowermd/lib/python3.12/site-packages/gmso/core/element.py:10: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import resource_filename

# %%
class DPD_AA_FF(BaseHOOMDForcefield):
    def __init__(
        self,
        epsilon,
        A,
        gamma,
        kT,
        r_cut,
        bond_k,
        bond_r0,
        angle_k,
        angle_theta0,
    ):
        self.epsilon = epsilon
        self.gamma = gamma
        self.A = A
        self.kT = kT
        self.r_cut = r_cut
        self.bond_k = bond_k
        self.bond_r0 = bond_r0
        self.angle_k = angle_k
        self.angle_theta0 = angle_theta0
        hoomd_forces = self._create_forcefield()
        super(DPD_AA_FF, self).__init__(hoomd_forces)

    def _create_forcefield(self):
        forces = []
        #opls = forcefields.FF_from_file('pps_opls.xml')
        #print(opls)
        #forces.append(opls.hoomd_forces)
        #use non-bonded epsilons and sigmas to scale A and gamma for each atom type
        #use bonds, angles, and dihedrals as is
        # add bonds, angles and dihedrals to the hoomd simulation
        nlist = hoomd.md.nlist.Cell(buffer=0.40, exclusions=["body"])
        dpd = hoomd.md.pair.DPD(nlist=nlist,kT=self.kT,default_r_cut=self.r_cut)
        for pair in [ #zero pairs for hydrogen interactions
            ("H", "H"),
            ("H", "C"),
            ("H", "S"),
        ]:
            dpd.params[pair] = dict(A=0,gamma=0.1)
            dpd.params[pair].r_cut = 0.0

        cc_factor = nonbondedforce['ca']['epsilon']/nonbondedforce['sh']['epsilon']
        dpd.params[("C","C")] = dict(A=self.A*cc_factor,gamma=self.gamma*cc_factor)
        dpd.params[("C","C")].r_cut = self.r_cut
        cs_factor = nonbondedforce['s']['epsilon']/nonbondedforce['sh']['epsilon']
        dpd.params[("C","S")] = dict(A=self.A*cs_factor,gamma=self.gamma*cs_factor)
        dpd.params[("C","S")].r_cut = self.r_cut
        ss_factor = nonbondedforce['s']['epsilon']/nonbondedforce['sh']['epsilon']
        dpd.params[("S","S")] = dict(A=self.A*ss_factor,gamma=self.gamma*ss_factor)
        dpd.params[("S","S")].r_cut = self.r_cut
        forces.append(dpd)

        #use bonds, angles, and dihedrals from file if possible
        # add bonds, angles and dihedrals to the hoomd simulation
        bond = hoomd.md.bond.Harmonic()
        bond.params["H-C"] = dict(k=self.bond_k, r0=self.bond_r0)
        bond.params["C-H"] = dict(k=self.bond_k, r0=self.bond_r0)
        bond.params["C-C"] = dict(k=self.bond_k, r0=self.bond_r0)
        bond.params["C-S"] = dict(k=self.bond_k, r0=self.bond_r0)
        bond.params["S-H"] = dict(k=self.bond_k, r0=self.bond_r0)
        bond.params["S-S"] = dict(k=0, r0=0)
        bond.params["H-H"] = dict(k=0, r0=0)
        forces.append(bond)
        return forces
''' angles are missing from back-mapping method
        angle = hoomd.md.angle.Harmonic()
        angle.params["C-C-C"] = dict(k=self.angle_k, t0=self.angle_theta0)
        angle.params["C-C-H"] = dict(k=self.angle_k, t0=self.angle_theta0)
        angle.params["C-H-C"] = dict(k=self.angle_k, t0=self.angle_theta0)
        angle.params["H-C-C"] = dict(k=self.angle_k, t0=self.angle_theta0)
        angle.params["H-H-C"] = dict(k=self.angle_k, t0=self.angle_theta0)
        angle.params["C-H-H"] = dict(k=self.angle_k, t0=self.angle_theta0)
        angle.params["H-C-H"] = dict(k=self.angle_k, t0=self.angle_theta0)
        angle.params["H-H-H"] = dict(k=self.angle_k, t0=self.angle_theta0)
        angle.params["H-C-S"] = dict(k=self.angle_k, t0=self.angle_theta0)
        angle.params["C-S-H"] = dict(k=self.angle_k, t0=self.angle_theta0)
        angle.params["C-S-C"] = dict(k=self.angle_k, t0=self.angle_theta0)
        angle.params["S-C-H"] = dict(k=self.angle_k, t0=self.angle_theta0)
        angle.params["S-C-C"] = dict(k=self.angle_k, t0=self.angle_theta0)
        forces.append(angle)
'''
# Out:
# ' angles are missing from back-mapping method\n        angle = hoomd.md.angle.Harmonic()\n        angle.params["C-C-C"] = dict(k=self.angle_k, t0=self.angle_theta0)\n        angle.params["C-C-H"] = dict(k=self.angle_k, t0=self.angle_theta0)\n        angle.params["C-H-C"] = dict(k=self.angle_k, t0=self.angle_theta0)\n        angle.params["H-C-C"] = dict(k=self.angle_k, t0=self.angle_theta0)\n        angle.params["H-H-C"] = dict(k=self.angle_k, t0=self.angle_theta0)\n        angle.params["C-H-H"] = dict(k=self.angle_k, t0=self.angle_theta0)\n        angle.params["H-C-H"] = dict(k=self.angle_k, t0=self.angle_theta0)\n        angle.params["H-H-H"] = dict(k=self.angle_k, t0=self.angle_theta0)\n        angle.params["H-C-S"] = dict(k=self.angle_k, t0=self.angle_theta0)\n        angle.params["C-S-H"] = dict(k=self.angle_k, t0=self.angle_theta0)\n        angle.params["C-S-C"] = dict(k=self.angle_k, t0=self.angle_theta0)\n        angle.params["S-C-H"] = dict(k=self.angle_k, t0=self.angle_theta0)\n        angle.params["S-C-C"] = dict(k=self.angle_k, t0=self.angle_theta0)\n        forces.append(angle)\n'

# %%
from flowermd.library import OPLS_AA_PPS

# %%
simulation = hoomd.Simulation(device=hoomd.device.auto_select(), seed=np.random.randint(65535))# TODO seed
simulation.operations.integrator = integrator 
simulation.create_state_from_snapshot(frame)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 2
#       1 simulation = hoomd.Simulation(device=hoomd.device.auto_select(), seed=np.random.randint(65535))# TODO seed
# ----> 2 simulation.operations.integrator = integrator
#       3 simulation.create_state_from_snapshot(frame)
#
# NameError: name 'integrator' is not defined

# %%
non_bonded_ff = DPD_AA_FF(epsilon=1.0,A=5000,gamma=800,kT=1.0,r_cut=1.15,bond_k=15000,bond_r0=1.0,angle_k=15000,angle_theta0=1.8)

#opls_ff = forcefields.FF_from_file('pps_opls.xml')
sim = Simulation(
    initial_state='pps-from-dpd-single-chain.gsd',
    forcefield=non_bonded_ff.hoomd_forces,
    dt=0.001,
    gsd_write_freq=int(100),
    gsd_file_name='trajectory.gsd',
    log_write_freq=int(100),
    log_file_name='log.txt')

sim.save_restart_gsd()
sim.run_NVT(n_steps=1e4, kT=1.0, tau_kt=10*sim.dt)
sim.flush_writers()
# Out:
# Initializing simulation state from a GSD file.
# Step 100 of 10000; TPS: 619.52; ETA: 0.3 minutes
# Step 200 of 10000; TPS: 1233.72; ETA: 0.1 minutes
# Step 300 of 10000; TPS: 1844.02; ETA: 0.1 minutes
# Step 400 of 10000; TPS: 2451.34; ETA: 0.1 minutes
# Step 500 of 10000; TPS: 3055.28; ETA: 0.1 minutes
# Step 600 of 10000; TPS: 3655.97; ETA: 0.0 minutes
# Step 700 of 10000; TPS: 4253.35; ETA: 0.0 minutes
# Step 800 of 10000; TPS: 4847.46; ETA: 0.0 minutes
# Step 900 of 10000; TPS: 5437.94; ETA: 0.0 minutes
# Step 1000 of 10000; TPS: 6024.79; ETA: 0.0 minutes
# Step 1100 of 10000; TPS: 6608.67; ETA: 0.0 minutes
# Step 1200 of 10000; TPS: 7189.24; ETA: 0.0 minutes
# Step 1300 of 10000; TPS: 7766.57; ETA: 0.0 minutes
# Step 1400 of 10000; TPS: 8340.68; ETA: 0.0 minutes
# Step 1500 of 10000; TPS: 8911.01; ETA: 0.0 minutes
# Step 1600 of 10000; TPS: 9478.28; ETA: 0.0 minutes
# Step 1700 of 10000; TPS: 10041.76; ETA: 0.0 minutes
# Step 1800 of 10000; TPS: 10601.83; ETA: 0.0 minutes
# Step 1900 of 10000; TPS: 11157.83; ETA: 0.0 minutes
# Step 2000 of 10000; TPS: 11662.01; ETA: 0.0 minutes
# Step 2100 of 10000; TPS: 12207.95; ETA: 0.0 minutes
# Step 2200 of 10000; TPS: 12749.78; ETA: 0.0 minutes
# Step 2300 of 10000; TPS: 13288.35; ETA: 0.0 minutes
# Step 2400 of 10000; TPS: 13823.53; ETA: 0.0 minutes
# Step 2500 of 10000; TPS: 14296.82; ETA: 0.0 minutes
# Step 2600 of 10000; TPS: 14823.51; ETA: 0.0 minutes
# Step 2700 of 10000; TPS: 15347.45; ETA: 0.0 minutes
# Step 2800 of 10000; TPS: 15868.97; ETA: 0.0 minutes
# Step 2900 of 10000; TPS: 16387.33; ETA: 0.0 minutes
# Step 3000 of 10000; TPS: 16901.79; ETA: 0.0 minutes
# Step 3100 of 10000; TPS: 17413.87; ETA: 0.0 minutes
# Step 3200 of 10000; TPS: 17922.25; ETA: 0.0 minutes
# Step 3300 of 10000; TPS: 18426.8; ETA: 0.0 minutes
# Step 3400 of 10000; TPS: 18929.06; ETA: 0.0 minutes
# Step 3500 of 10000; TPS: 19428.58; ETA: 0.0 minutes
# Step 3600 of 10000; TPS: 19923.85; ETA: 0.0 minutes
# Step 3700 of 10000; TPS: 20416.16; ETA: 0.0 minutes
# Step 3800 of 10000; TPS: 20905.54; ETA: 0.0 minutes
# Step 3900 of 10000; TPS: 21391.31; ETA: 0.0 minutes
# Step 4000 of 10000; TPS: 21874.9; ETA: 0.0 minutes
# Step 4100 of 10000; TPS: 22354.9; ETA: 0.0 minutes
# Step 4200 of 10000; TPS: 22831.42; ETA: 0.0 minutes
# Step 4300 of 10000; TPS: 23302.95; ETA: 0.0 minutes
# Step 4400 of 10000; TPS: 23772.6; ETA: 0.0 minutes
# Step 4500 of 10000; TPS: 24239.94; ETA: 0.0 minutes
# Step 4600 of 10000; TPS: 24619.47; ETA: 0.0 minutes
# Step 4700 of 10000; TPS: 25079.78; ETA: 0.0 minutes
# Step 4800 of 10000; TPS: 25537.21; ETA: 0.0 minutes
# Step 4900 of 10000; TPS: 25991.11; ETA: 0.0 minutes
# Step 5000 of 10000; TPS: 26441.88; ETA: 0.0 minutes
# Step 5100 of 10000; TPS: 26890.22; ETA: 0.0 minutes
# Step 5200 of 10000; TPS: 27336.05; ETA: 0.0 minutes
# Step 5300 of 10000; TPS: 27779.38; ETA: 0.0 minutes
# Step 5400 of 10000; TPS: 28219.06; ETA: 0.0 minutes
# Step 5500 of 10000; TPS: 28657.18; ETA: 0.0 minutes
# Step 5600 of 10000; TPS: 29091.51; ETA: 0.0 minutes
# Step 5700 of 10000; TPS: 29523.43; ETA: 0.0 minutes
# Step 5800 of 10000; TPS: 29953.88; ETA: 0.0 minutes
# Step 5900 of 10000; TPS: 30378.55; ETA: 0.0 minutes
# Step 6000 of 10000; TPS: 30801.61; ETA: 0.0 minutes
# Step 6100 of 10000; TPS: 31220.25; ETA: 0.0 minutes
# Step 6200 of 10000; TPS: 31638.79; ETA: 0.0 minutes
# Step 6300 of 10000; TPS: 32051.12; ETA: 0.0 minutes
# Step 6400 of 10000; TPS: 32464.24; ETA: 0.0 minutes
# Step 6500 of 10000; TPS: 32870.78; ETA: 0.0 minutes
# Step 6600 of 10000; TPS: 33279.72; ETA: 0.0 minutes
# Step 6700 of 10000; TPS: 33683.58; ETA: 0.0 minutes
# Step 6800 of 10000; TPS: 34089.14; ETA: 0.0 minutes
# Step 6900 of 10000; TPS: 34488.62; ETA: 0.0 minutes
# Step 7000 of 10000; TPS: 34765.85; ETA: 0.0 minutes
# Step 7100 of 10000; TPS: 35161.05; ETA: 0.0 minutes
# Step 7200 of 10000; TPS: 35557.49; ETA: 0.0 minutes
# Step 7300 of 10000; TPS: 35948.9; ETA: 0.0 minutes
# Step 7400 of 10000; TPS: 36342.74; ETA: 0.0 minutes
# Step 7500 of 10000; TPS: 36731.22; ETA: 0.0 minutes
# Step 7600 of 10000; TPS: 37118.62; ETA: 0.0 minutes
# Step 7700 of 10000; TPS: 37502.25; ETA: 0.0 minutes
# Step 7800 of 10000; TPS: 37885.78; ETA: 0.0 minutes
# Step 7900 of 10000; TPS: 38263.51; ETA: 0.0 minutes
# Step 8000 of 10000; TPS: 38643.05; ETA: 0.0 minutes
# Step 8100 of 10000; TPS: 39015.09; ETA: 0.0 minutes
# Step 8200 of 10000; TPS: 39390.31; ETA: 0.0 minutes
# Step 8300 of 10000; TPS: 39759.53; ETA: 0.0 minutes
# Step 8400 of 10000; TPS: 40130.33; ETA: 0.0 minutes
# Step 8500 of 10000; TPS: 40496.05; ETA: 0.0 minutes
# Step 8600 of 10000; TPS: 40859.96; ETA: 0.0 minutes
# Step 8700 of 10000; TPS: 41219.92; ETA: 0.0 minutes
# Step 8800 of 10000; TPS: 41583.19; ETA: 0.0 minutes
# Step 8900 of 10000; TPS: 41939.79; ETA: 0.0 minutes
# Step 9000 of 10000; TPS: 42298.8; ETA: 0.0 minutes
# Step 9100 of 10000; TPS: 42655.12; ETA: 0.0 minutes
# Step 9200 of 10000; TPS: 43012.96; ETA: 0.0 minutes
# Step 9300 of 10000; TPS: 43364.33; ETA: 0.0 minutes
# Step 9400 of 10000; TPS: 43718.49; ETA: 0.0 minutes
# Step 9500 of 10000; TPS: 44067.58; ETA: 0.0 minutes
# Step 9600 of 10000; TPS: 44419.77; ETA: 0.0 minutes
# Step 9700 of 10000; TPS: 44766.89; ETA: 0.0 minutes
# Step 9800 of 10000; TPS: 45114.3; ETA: 0.0 minutes
# Step 9900 of 10000; TPS: 45458.72; ETA: 0.0 minutes

# %%
opls = forcefields.FF_from_file('pps_opls.xml')

# %%
opls.gmso_ff

# %%
opls.gmso_ff.angle_types

# %%
opls.gmso_ff.atom_types

# %%
opls.gmso_ff.pairpotential_types

# %%
opls.gmso_ff.get_potential

# %%
opls.gmso_ff.to_xml('pps-opls-dpd.xml')

# %%
traj = gsd.hoomd.open('pps-from-dpd-single-chain.gsd','r')

# %%
frame = traj[-1]

# %%
frame.angles.typeid

# %%
frame.bonds.types

# %%
frame.angles.N

# %%
frame.dihedrals.N

# %%
frame.dihedrals.types

# %%
angles = np.array(angles)
dihedrals = np.array(dihedrals)
frame = gsd.hoomd.Frame()
frame.particles.types = ['A']
frame.particles.N = N
frame.particles.position = positions
frame.bonds.N = len(bonds)
frame.bonds.group = bonds
frame.bonds.types = ['b']
frame.angles.N = (num_mon - 2)*num_pol
frame.angles.types = ["A-A-A"]
frame.angles.group = angles
frame.dihedrals.N = (num_mon - 3)*num_pol
frame.dihedrals.types = ["A-A-A-A"]
frame.dihedrals.group = dihedrals
frame.configuration.box = [L, L, L, 0, 0, 0]
build_stop = time.perf_counter()
print("Total build time: ", build_stop-start_time)
harmonic = hoomd.md.bond.Harmonic()
harmonic.params["b"] = dict(r0=bond_l, k=k)
integrator = hoomd.md.Integrator(dt=dt)
integrator.forces.append(harmonic)
simulation = hoomd.Simulation(device=hoomd.device.auto_select(), seed=np.random.randint(65535))# TODO seed
simulation.operations.integrator = integrator 
simulation.create_state_from_snapshot(frame)
const_vol = hoomd.md.methods.ConstantVolume(filter=hoomd.filter.All())
integrator.methods.append(const_vol)
nlist = hoomd.md.nlist.Cell(buffer=0.4)
simulation.operations.nlist = nlist
DPD = hoomd.md.pair.DPD(nlist, default_r_cut=r_cut, kT=kT)
DPD.params[('A', 'A')] = dict(A=A, gamma=gamma)
integrator.forces.append(DPD)

gsd_out = hoomd.write.GSD(
    trigger=hoomd.trigger.Periodic(100),
    mode='wb',
    dynamic=['property', 'momentum'],
    filename='bead-spring-dpd-single-chain.gsd')

simulation.operations.writers.append(gsd_out)

simulation.run(0)
