# %% [markdown]
# ### Notebook for initializing polymer systems using a DPD potential

# %%
import matplotlib
import numpy as np  
import scipy.stats
import gsd, gsd.hoomd 
import freud 
import math
import itertools 
import hoomd 
import fresnel 
# %matplotlib inline
matplotlib.style.use("ggplot")
import matplotlib_inline
matplotlib_inline.backend_inline.set_matplotlib_formats("svg")

# %%
import time

# %%
def render(frame): 
    '''
    Visualize a simulation box within a jupyter notebook.
    
    '''
    scene = fresnel.Scene()
    geometry = fresnel.geometry.Sphere(scene, N=frame.particles.N)
    geometry.material = fresnel.material.Material(color=fresnel.color.linear([0.01, 0.74, 0.26]), roughness=0.5)
    geometry.position[:] = frame.particles.position
    geometry.outline_width = 0.01
    box = fresnel.geometry.Box(scene, frame.configuration.box,box_radius=0.01)
    L = frame.configuration.box[0]
    scene.camera = fresnel.camera.Perspective(position=(L*1.8, L*1.8, L * 2.2), look_at=(0, 0, 0), up=(0, 1, 0), height=0.28)

    if frame.bonds.N>0:
        geometry.radius[:] = [0.2]*frame.particles.N 

        all_bonds = np.stack(
        [
            frame.particles.position[frame.bonds.group[:, 0]],
            frame.particles.position[frame.bonds.group[:, 1]],
        ],
        axis=1,
        )
        bond_distances = np.linalg.norm(all_bonds[:,0,:]-all_bonds[:,1,:], axis=1)
        L = frame.configuration.box[0]
        bond_indices = np.where(bond_distances < L/2)[0]
        filtered_bonds = all_bonds[bond_indices, :, :]
        
        bonds = fresnel.geometry.Cylinder(scene, N=len(filtered_bonds))
        bonds.material = fresnel.material.Material(roughness=0.5)
        bonds.outline_width = 0.05

        bonds.points[:] = filtered_bonds
        bonds.radius[:] = [0.1]*len(filtered_bonds)
        bonds.material.primitive_color_mix = 1.0
        bonds.color[:] = fresnel.color.linear([0.8, 0.8, 0.8])
                
    return fresnel.preview(scene)

# %%
def initialize_snapshot(num_pol, num_mon, density=0.85):
    
    Create a HOOMD snapshot of a cubic box with the number density given by input parameters.

    
    N = num_pol * num_mon
    L = np.cbrt(N / density)  # Calculate box size based on density
    buffer = 4
    print(L)
    #TODO: change to random walk
    positions = np.random.uniform(low=-(0.5), high=(0.5), size=(N, 3))
    bonds = []
    for i in range(num_pol):
        start = i * num_mon
        for j in range(num_mon - 1):
            bonds.append([start + j, start + j + 1])
    bonds = np.array(bonds)
    frame = gsd.hoomd.Frame()
    frame.particles.types = ['A']
    frame.particles.N = N
    frame.particles.position = positions
    frame.bonds.N = len(bonds)
    frame.bonds.group = bonds
    frame.bonds.types = ['b']
    frame.configuration.box = [L, L, L, 0, 0, 0]
    return frame
# Out:
#   Cell In[4], line 1
#     '''
#     ^
# IndentationError: unexpected indent

# %%
import mbuild as mb
from mbuild.path import HardSphereRandomWalk
from mbuild.utils.geometry import bounding_box
from mbuild.utils.volumes import (
    CuboidConstraint)

def rand_walk_inside_cube(num_pol,num_mon,density):
    N = num_pol * num_mon
    L = np.cbrt(N / density)  # Calculate box size based on density
    buffer = 0.5
    cube = CuboidConstraint(Lx=L-0.5, Ly=L-0.5, Lz=L-0.5)
    n_chains = num_pol
    chain_length = num_mon
    seeds = [np.random.randint(low=1) for i in range(n_chains)]
    chains = []
    for seed in seeds:    
        rw_path = HardSphereRandomWalk(
                N=chain_length,
                bond_length=0.9,
                radius=0.1,
                volume_constraint=cube,
                min_angle=np.pi / 4,
                max_angle=np.pi,
                max_attempts=1e3,
                seed=seed,
            )
        rw_path.generate()
        
        chain = Polymer()
        chain.build_from_path(path=rw_path, energy_minimize=True)
        chains.append(chain)
        
    bounds = bounding_box(rw_path.coordinates)
    return chains, bounds

# %%
chains = rand_walk_inside_cube(num_pol=20,num_mon=10,density=0.8)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 chains = rand_walk_inside_cube(num_pol=20,num_mon=10,density=0.8)
#
# Cell In[14], line 27, in rand_walk_inside_cube(num_pol, num_mon, density)
#      16 for seed in seeds:
#      17     rw_path = HardSphereRandomWalk(
#      18             N=chain_length,
#      19             bond_length=0.9,
#    (...)     25             seed=seed,
#      26         )
# ---> 27     rw_path.generate()
#      29     chain = Polymer()
#      30     #ethane = mb.load("CC", smiles=True)
#      31     #chain.add_monomer(compound=ethane, indices=[2, 6], replace=True, separation=0.154)
#
# File ~/Desktop/cmelab/base/mupt-examples/repos/mbuild/mbuild/path/path.py:298, in HardSphereRandomWalk.generate(self)
#     293 self.coordinates[1] = self.coordinates[0] + xyz
#     294 self.count += 1
#     295 self.bond_graph.add_node(
#     296     self.count,
#     297     name=self.bead_name,
# --> 298     xyz=self.coordinates[self.count],
#     299 )
#     300 self.add_edge(u=self.count - 1, v=self.count)
#     301 self.attempts += 1
#
# IndexError: index 10 is out of bounds for axis 0 with size 10

# %%
def pbc(d,box):
    for i in range(3):
        a = d[:,i]
        a[a < -box[i]/2] += box[i]
        a[a >  box[i]/2] -= box[i]
    return d

# %%
def check_bond_length_equillibration(gsdfile,bond_length,num_mon,num_pol):
    fene_bond_l = bond_length
    traj = gsd.hoomd.open(gsdfile)
    last_frame = traj[-1]
    frame_ds = []
    for j in range(num_pol):
        idx = j*num_mon
        d1 = last_frame.particles.position[idx:idx+num_mon-1] - last_frame.particles.position[idx+1:idx+num_mon]
        bond_l = np.linalg.norm(pbc(d1,frame.configuration.box),axis=1)
        frame_ds.append(bond_l)
    max_frame_bond_l = np.max(np.array(frame_ds))
    min_frame_bond_l = np.min(np.array(frame_ds))
    print("max: ",max_frame_bond_l," min: ",min_frame_bond_l)
    if max_frame_bond_l <= fene_bond_l and min_frame_bond_l >= (fene_bond_l - 0.3):
        print("DPD Simulation Finished.")
        return True
    if max_frame_bond_l > fene_bond_l or min_frame_bond_l < (fene_bond_l - 0.3):
        return False

# %% [markdown]
# ## Parameters

# %%
num_pol = 50
num_mon = 50
kT = 2.0
cut = 2.5
l = 1.0 #bond length r_0
timestep = 0.001
gamma = 0.1 #DPD parameter
A = 50.0 #DPD parameter

# %% [markdown]
# ## HOOMD simulation code

# %%
frame = initialize_snapshot(num_pol, num_mon, density=density)
# Out:
# Box size: 26.099

# %%
print(frame.particles.position)
# Out:
# [[[ 4.25173437  5.21912758  6.29612458]]
#
#  [[ 3.64647929  4.42609712  6.22706685]]
#
#  [[ 4.36163872  4.7688364   5.61790614]]
#
#  ...
#
#  [[ 9.17980774  3.64908694 -4.17329195]]
#
#  [[ 9.92287521  3.25663167 -3.63123144]]
#
#  [[10.62613407  3.96705578 -3.65814912]]]

# %%
start_time = time.perf_counter

num_pol = 400
num_mon = 40
kT = 1.0
cut = 1.2
l = 1.0 #bond length r_0
timestep = 0.001
gamma = 400.0 #DPD parameter
A = 5000.0 #DPD parameter, A scales down with N
k=10000
density = 0.9

frame = initialize_snapshot(num_pol, num_mon, density=density)

#assign harmonic bond potentials
harmonic = hoomd.md.bond.Harmonic()
harmonic.params["b"] = dict(r0=l, k=k)

integrator = hoomd.md.Integrator(dt=timestep)
integrator.forces.append(harmonic)

#initialize HOOMD simulation object
simulation = hoomd.Simulation(device=hoomd.device.auto_select(),seed=12)
simulation.operations.integrator = integrator 
simulation.create_state_from_snapshot(frame) #create initial state of Simulation

#add ensemble method to Simulation
const_vol = hoomd.md.methods.ConstantVolume(filter=hoomd.filter.All())
integrator.methods.append(const_vol)

#define the neighbor list
nlist = hoomd.md.nlist.Cell(buffer=0.4)
simulation.operations.nlist = nlist

#define the forcefield
DPD = hoomd.md.pair.DPD(nlist, default_r_cut=cut, kT=kT)
DPD.params[('A', 'A')] = dict(A=A, gamma=gamma)
integrator.forces.append(DPD)
simulation.operations.integrator = integrator

#define write frequency for trajectory file
gsd_out = hoomd.write.GSD(
    trigger=hoomd.trigger.Periodic(10), 
    mode='wb',
    dynamic=['property','momentum'],
    filename='run_len_%s_pol_%s.gsd'%(num_mon,num_pol),
    truncate=False)
simulation.operations.writers.append(gsd_out)

#run the simulation! and log by flushing the writers
simulation.run(100)
gsd_out.flush()

fene_bond_l = 1.2
file = 'run_len_%s_pol_%s.gsd'%(num_mon,num_pol)
count = 1000


while not check_bond_length_equillibration(file,fene_bond_l,num_mon,num_pol):
    simulation.run(1000)
    gsd_out.flush()
    count += 1000
render(simulation.state.get_snapshot())
print(f"Finished in {count} iterations.")
end_time = time.perf_counter
total_time = end_time-start_time
print("total time: ",total_time)
# Out:
# Box size: 26.099
# max:  1.5931346  min:  0.44762433
# max:  1.1212424  min:  0.8070919
# max:  1.0691397  min:  0.8710645
# max:  1.0636678  min:  0.909832
# DPD Simulation Finished.
# Finished in 4000 iterations.

# %% [markdown]
# ## Run code

# %%
#run the simulation! and log by flushing the writers
simulation.run(1_000)
gsd_out.flush()

fene_bond_l = 1.2
file = 'run_len_%s_pol_%s.gsd'%(num_mon,num_pol)
count = 1000


while not check_bond_length_equillibration(file,fene_bond_l,num_mon,num_pol):
    simulation.run(200)
    gsd_out.flush()
    count += 200
render(simulation.state.get_snapshot())
print(f"Finished in {count} iterations.")
# Out:
# max bond length:  7.683396
# min bond length:  0.23592383
# max bond length:  7.369175
# min bond length:  0.21894705
# max bond length:  7.587952
# min bond length:  0.27974385
# max bond length:  1.1972176
# min bond length:  0.72623944
# max bond length:  1.2614985
# min bond length:  0.704443
# max bond length:  1.1677132
# min bond length:  0.71034074
# max bond length:  1.2370209
# min bond length:  0.69056743
# max bond length:  1.1899735
# min bond length:  0.71247977
# max bond length:  1.2132937
# min bond length:  0.7208057
# max bond length:  1.2421429
# min bond length:  0.7429831
# max bond length:  1.2766652
# min bond length:  0.6714594
# max bond length:  1.1752687
# min bond length:  0.6908778
# max bond length:  1.1904672
# min bond length:  0.70222574
# max bond length:  1.1670164
# min bond length:  0.68091625
# max bond length:  1.1688653
# min bond length:  0.6697795
# max bond length:  1.1787682
# min bond length:  0.6805235
# max bond length:  1.2172142
# min bond length:  0.6950365
# max bond length:  1.1936967
# min bond length:  0.70268315
# max bond length:  1.1968222
# min bond length:  0.6941931
# max bond length:  1.1972929
# min bond length:  0.7202327
# max bond length:  1.2041876
# min bond length:  0.67958987
# max bond length:  1.1661695
# min bond length:  0.7363659
# max bond length:  1.1683583
# min bond length:  0.7077292
# max bond length:  1.1490955
# min bond length:  0.6781013
# max bond length:  1.2258841
# min bond length:  0.65449786
# max bond length:  1.2083911
# min bond length:  0.6422214
# max bond length:  1.1819328
# min bond length:  0.61940384
# max bond length:  1.1679276
# min bond length:  0.72923994
# max bond length:  1.1877356
# min bond length:  0.67987376
# max bond length:  1.1764253
# min bond length:  0.6720438
# max bond length:  1.2400185
# min bond length:  0.7232313
# max bond length:  1.180924
# min bond length:  0.6876373
# max bond length:  1.1968911
# min bond length:  0.6758004
# max bond length:  1.2288222
# min bond length:  0.7113606
# max bond length:  1.1903588
# min bond length:  0.6741241
# max bond length:  1.1750154
# min bond length:  0.65388775
# max bond length:  1.2358352
# min bond length:  0.73405886
# max bond length:  1.2507478
# min bond length:  0.70643085
# max bond length:  1.2173826
# min bond length:  0.68353635
# max bond length:  1.2036419
# min bond length:  0.68956167
# max bond length:  1.2020802
# min bond length:  0.68831736
# max bond length:  1.1762825
# min bond length:  0.69585097
# max bond length:  1.2088104
# min bond length:  0.7085489
# max bond length:  1.1783073
# min bond length:  0.6847517
# max bond length:  1.1610357
# min bond length:  0.7292142
# max bond length:  1.1819963
# min bond length:  0.6798861
# max bond length:  1.1770712
# min bond length:  0.69713056
# max bond length:  1.2071735
# min bond length:  0.73219395
# max bond length:  1.1741335
# min bond length:  0.7196199
# max bond length:  1.1842215
# min bond length:  0.72250783
# max bond length:  1.1508278
# min bond length:  0.7114498
# max bond length:  1.2141885
# min bond length:  0.68945026
# max bond length:  1.2130599
# min bond length:  0.7002048
# max bond length:  1.1827399
# min bond length:  0.64183205
# max bond length:  1.1732347
# min bond length:  0.71597093
# max bond length:  1.1864842
# min bond length:  0.73017514
# max bond length:  1.2336693
# min bond length:  0.6901546
# max bond length:  1.197294
# min bond length:  0.7076567
# max bond length:  1.1747231
# min bond length:  0.70502377
# max bond length:  1.2783868
# min bond length:  0.7137268
# max bond length:  1.1939261
# min bond length:  0.69142586
# min bond length:  0.6860366
# max bond length:  1.2112767
# min bond length:  0.71755636
# max bond length:  1.1824356
# min bond length:  0.6999411
# max bond length:  1.2262414
# min bond length:  0.7100124
# max bond length:  1.1790584
# min bond length:  0.6779667
# max bond length:  1.2069719
# min bond length:  0.6590229
# max bond length:  1.229363
# min bond length:  0.7015249
# max bond length:  1.1830754
# min bond length:  0.6707817
# max bond length:  1.1828222
# min bond length:  0.71389097
# max bond length:  1.2157761
# min bond length:  0.72255164
# max bond length:  1.1834307
# min bond length:  0.7015201
# max bond length:  1.1729693
# min bond length:  0.6979337
# max bond length:  1.1579369
# min bond length:  0.7091056
# max bond length:  1.1906428
# min bond length:  0.72064275
# max bond length:  1.1655756
# min bond length:  0.7032612
# max bond length:  1.2196991
# min bond length:  0.70606005
# max bond length:  1.2135003
# min bond length:  0.71751183
# max bond length:  1.2150797
# min bond length:  0.71074575
# max bond length:  1.200423
# min bond length:  0.71282727
# max bond length:  1.1756536
# min bond length:  0.6957631
# max bond length:  1.2504556
# min bond length:  0.68879783
# max bond length:  1.1760029
# min bond length:  0.69381666
# max bond length:  1.2093529
# min bond length:  0.7027421
# max bond length:  1.2187133
# min bond length:  0.70459926
# max bond length:  1.2109414
# min bond length:  0.694323
# max bond length:  1.183154
# min bond length:  0.70654446
# max bond length:  1.1583331
# min bond length:  0.71008825
# max bond length:  1.2086769
# min bond length:  0.67561543
# max bond length:  1.2045758
# min bond length:  0.6787925
# max bond length:  1.2173405
# min bond length:  0.6686483
# max bond length:  1.1990817
# min bond length:  0.6952675
# max bond length:  1.1590513
# min bond length:  0.7328301
# max bond length:  1.189316
# min bond length:  0.7143393
# max bond length:  1.2104896
# min bond length:  0.6731204
# max bond length:  1.188398
# min bond length:  0.6567977
# max bond length:  1.2234654
# min bond length:  0.72051203
# max bond length:  1.2203429
# min bond length:  0.7181199
# max bond length:  1.1939015
# min bond length:  0.70715284
# max bond length:  1.1647992
# min bond length:  0.68536085
# max bond length:  1.2069188
# min bond length:  0.70004904
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[37], line 11
#       7 count = 1000
#      10 while not check_bond_length_equillibration(file,fene_bond_l,num_mon,num_pol):
# ---> 11     simulation.run(200)
#      12     gsd_out.flush()
#      13     count += 200
#
# File ~/miniforge3/envs/flowermd/lib/python3.12/site-packages/hoomd/simulation.py:561, in Simulation.run(self, steps, write_at_start)
#     558 if steps_int < 0 or steps_int > TIMESTEP_MAX - 1:
#     559     raise ValueError(f"steps must be in the range [0, {TIMESTEP_MAX - 1}]")
# --> 561 self._cpp_sys.run(steps_int, write_at_start)
#
# KeyboardInterrupt:

# %% [markdown]
# ### Graph the bond length relaxation

# %%
import matplotlib.pyplot as plt

with gsd.hoomd.open('run_len_%s_pol_%s.gsd'%(num_mon,num_pol),'r') as traj:
    avg_frame_bond_l = []
    for frame in traj:
        bond_l = []
        for i in range(0,num_mon-2):
            dr = np.linalg.norm((frame.particles.position[i+1] - frame.particles.position[i]), axis=0)
            bond_l.append(dr)
        avg_frame_bond_l.append(np.mean(bond_l))

plt.plot(avg_frame_bond_l)
