# %% [markdown]
# # Interfacing between the MuPT molecular representation and RDKit

# %% [markdown]
# ## Import from RDKit

# %%
from rdkit import Chem
from rdkit.Chem.AllChem import EmbedMolecule
from rdkit.Chem.Draw import IPythonConsole
IPythonConsole.molSize = (600, 300)
IPythonConsole.drawOptions.addAtomIndices = True


smi = '*CC(=O)O*'
smi = 'c1cc(*)ccc1-S(=O)(=O)-c1ccc(*)cc1'
smi = 'c1cc(*)ccc1-S(=O)(=O)-c1ccc(*)cc1.*CC(=O)O*'
smi = 'c1cc(C(-*)([C@@](Cl)(Br)(F)))ccc1-S(=O)(=O)-c1ccc(C=CC=CO-*)cc1'
# smi = 'c1cc(C([C@](Cl)(Br)(F)))ccc1-S(=O)(=O)-c1ccc(C=CCO)cc1'
# smi = r'C[C@H](CCCC(C)C)[C@H]1CC[C@@H]2[C@@]1(CC[C@H]3[C@H]2CC=C4[C@@]3(CC[C@@H](C4)O)C)C' # cholesterol
# smi = r'C/C=C(/C)\C(=O)O[C@H]1C(C)=C[C@]23[C@]1(O)[C@H](O)C(CO)=C[C@H](C3=O)[C@H]4[C@H](C4(C)C)C[C@H]2C' # ingenol
# smi = '*-OC[C@H]1OC=C[C@@H](O)[C@@H]1O-*'

mol = Chem.MolFromSmiles(smi, sanitize=False)
mol.UpdatePropertyCache()
mol = Chem.AddHs(mol)
Chem.SanitizeMol(mol, sanitizeOps=Chem.SanitizeFlags.SANITIZE_ALL)

for atom in mol.GetAtoms():
    # atom.SetAtomMapNum(atom.GetIdx() + 1)
    if atom.GetAtomicNum() == 0:
        atom.SetProp('dummyLabel', '*')
conf_id = EmbedMolecule(mol)
print(f'Conformer ID: {conf_id}')
# conf_id = EmbedMolecule(mol, clearConfs=False)
# print(f'Conformer ID: {conf_id}')

display(mol)
# Out:
# Conformer ID: 0
# [15:41:55] UFFTYPER: Unrecognized atom type: *_ (4)
# [15:41:55] UFFTYPER: Unrecognized atom type: *_ (24)

# %%
from mupt.interfaces.rdkit import (
    primitive_from_rdkit,
    chemical_graph_from_rdkit,
    connectors_from_rdkit,
)
from mupt.interfaces.smiles import primitive_from_smiles
from mupt.geometry.shapes import PointCloud


conf_id = None if (n_conf := mol.GetNumConformers()) == 0 else (n_conf - 1)
print(f'{conf_id=}')
# prim = primitive_from_rdkit(mol, conformer_id=conf_id)
prim = primitive_from_smiles(smi, ensure_explicit_Hs=True, embed_positions=True)
# prim = prim.children[1]
# print(prim)
print(repr(prim))

print(prim.num_atoms, prim.functionality)
if isinstance(prim.shape, PointCloud):
    print(f'Conformer shape: {prim.shape.positions.shape}')
# display(prim.connectors)
display(prim.external_connectors)
prim.visualize_topology()
# Out:
# conf_id=0
# Primitive(shape=PointCloud, functionality=2, topology=TopologicalStructure(num_objects=38, indiscrete=False), element=None, label=*OC([H])=C([H])C([H])=C([H])c1c([H])c([H])c(S(=O)(=O)c2c([H])c([H])c(C(*)([H])[C@@](F)(Cl)Br)c([H])c2[H])c([H])c1[H])
# 38 2
# Conformer shape: (38, 3)
# [15:41:56] UFFTYPER: Unrecognized atom type: *_ (4)
# [15:41:56] UFFTYPER: Unrecognized atom type: *_ (24)
# {(('Conn',),
#   0): ConnectorReference(primitive_handle=('ATOM', 23), connector_handle=(('Conn',), 1)),
#  (('Conn',),
#   1): ConnectorReference(primitive_handle=('ATOM', 3), connector_handle=(('Conn',), 1))}

# %%
## Visualize connections within Primitive
import matplotlib.pyplot as plt
import numpy as np


dim : float = 6
n_rows, n_cols = 1, 2
aspect = n_cols / n_rows
figsize = (aspect*dim, dim)

fig = plt.figure(figsize=figsize)
ax0 = fig.add_subplot(1, 2, 1, projection='3d')
ax0.set_title('Shape from toplevel Primitive')
if prim.shape is not None:
    _ = ax0.plot(*prim.shape.positions.T, 'o', markersize=5, color='b')

ax1 = fig.add_subplot(1, 2, 2, projection='3d')
ax1.set_title('Shape from aggregate of bottomlevel Primitives')
for subprim in prim.children:
    if subprim.shape is not None:
        _ = ax1.plot(*subprim.shape.positions.T, 'o-', markersize=5, color='g')
        
for (label1, label2) in prim.topology.edges:
    subprim1 = prim.children_by_handle[label1]
    subprim2 = prim.children_by_handle[label2]
    edge_endpoints = np.vstack([subprim1.shape.positions, subprim2.shape.positions])
    
    _ = ax1.plot(*edge_endpoints.T, 'o-', markersize=5, color='k')#, markersize=5, color='g')
    
for handle, connector in prim.connectors.items():
    ax1.quiver(*connector.anchor_position, *connector.bond_vector, color='r', arrow_length_ratio=0.1)

# %%
for subprim in prim.children:
    print(subprim)
    print(repr(subprim))
    print(subprim.num_atoms)
    print(subprim.canonical_form_connectors())
    
    for connector in subprim.connectors.values():
        if connector.has_dihedral_orientation:
            print(connector.tangent_vector)
            print(connector)
    print('==')
    # break
# Out:
# C(SINGLE:1-AROMATIC:2)[PointCloud]<5740354900026072187>-0
# Primitive(shape=PointCloud, functionality=3, topology=TopologicalStructure(num_objects=0, indiscrete=True), element=C, label=0)
# 1
# SINGLE:1-AROMATIC:2
# [-0.1341144   1.13646928 -0.27835263]
# Connector(anchor=AttachmentPoint(attachables={0}, attachment=0, position=array([ 2.94176338, -0.91190346,  0.67690827])), linker=AttachmentPoint(attachables={1}, attachment=1, position=array([ 3.88243957, -1.04945072, -0.33790686])), bondtype=rdkit.Chem.rdchem.BondType.AROMATIC, bond_length=np.float64(1.3905540898611215), label=('Conn',), dihedral_plane_set=True)
# [ 0.61195735  0.49889435 -0.88304998]
# Connector(anchor=AttachmentPoint(attachables={0}, attachment=0, position=array([ 2.94176338, -0.91190346,  0.67690827])), linker=AttachmentPoint(attachables={11}, attachment=11, position=array([2.31778709, 0.29619426, 0.92702575])), bondtype=rdkit.Chem.rdchem.BondType.AROMATIC, bond_length=np.float64(1.3825358077677747), label=('Conn',), dihedral_plane_set=True)
# [ 0.77404471 -0.68421974 -0.61875631]
# Connector(anchor=AttachmentPoint(attachables={0}, attachment=0, position=array([ 2.94176338, -0.91190346,  0.67690827])), linker=AttachmentPoint(attachables={27}, attachment=27, position=array([ 2.68125216, -1.76656982,  1.29610561])), bondtype=rdkit.Chem.rdchem.BondType.SINGLE, bond_length=np.float64(1.0870722272818036), label=('Conn',), dihedral_plane_set=True)
# ==
# C(SINGLE:1-AROMATIC:2)[PointCloud]<5740354900026072187>-1
# Primitive(shape=PointCloud, functionality=3, topology=TopologicalStructure(num_objects=0, indiscrete=True), element=C, label=1)
# 1
# SINGLE:1-AROMATIC:2
# [-0.13532977  1.14677131 -0.28087554]
# Connector(anchor=AttachmentPoint(attachables={1}, attachment=1, position=array([ 3.88243957, -1.04945072, -0.33790686])), linker=AttachmentPoint(attachables={0}, attachment=0, position=array([ 2.94176338, -0.91190346,  0.67690827])), bondtype=rdkit.Chem.rdchem.BondType.AROMATIC, bond_length=np.float64(1.3905540898611215), label=('Conn',), dihedral_plane_set=True)
# [-0.75744636  0.69584109  0.5955291 ]
# Connector(anchor=AttachmentPoint(attachables={1}, attachment=1, position=array([ 3.88243957, -1.04945072, -0.33790686])), linker=AttachmentPoint(attachables={2}, attachment=2, position=array([ 4.23537388,  0.0259258 , -1.14552878])), bondtype=rdkit.Chem.rdchem.BondType.AROMATIC, bond_length=np.float64(1.3904137691362246), label=('Conn',), dihedral_plane_set=True)
# [-0.70003359 -0.41476091  0.95107917]
# Connector(anchor=AttachmentPoint(attachables={1}, attachment=1, position=array([ 3.88243957, -1.04945072, -0.33790686])), linker=AttachmentPoint(attachables={28}, attachment=28, position=array([ 4.31118522, -2.03348148, -0.45146327])), bondtype=rdkit.Chem.rdchem.BondType.SINGLE, bond_length=np.float64(1.079367608374916), label=('Conn',), dihedral_plane_set=True)
# ==
# C(SINGLE:1-AROMATIC:2)[PointCloud]<5740354900026072187>-2
# Primitive(shape=PointCloud, functionality=3, topology=TopologicalStructure(num_objects=0, indiscrete=True), element=C, label=2)
# 1
# SINGLE:1-AROMATIC:2
# [ 0.82468094 -0.75783046 -0.64868828]
# Connector(anchor=AttachmentPoint(attachables={2}, attachment=2, position=array([ 4.23537388,  0.0259258 , -1.14552878])), linker=AttachmentPoint(attachables={1}, attachment=1, position=array([ 3.88243957, -1.04945072, -0.33790686])), bondtype=rdkit.Chem.rdchem.BondType.AROMATIC, bond_length=np.float64(1.3904137691362246), label=('Conn',), dihedral_plane_set=True)
# [ 0.09656948 -1.17328934  0.3347105 ]
# Connector(anchor=AttachmentPoint(attachables={2}, attachment=2, position=array([ 4.23537388,  0.0259258 , -1.14552878])), linker=AttachmentPoint(attachables={3}, attachment=3, position=array([ 5.23715537, -0.1922865 , -2.19947741])), bondtype=rdkit.Chem.rdchem.BondType.SINGLE, bond_length=np.float64(1.4703708562505204), label=('Conn',), dihedral_plane_set=True)
# [-0.63688375 -0.53421347  0.92469204]
# Connector(anchor=AttachmentPoint(attachables={2}, attachment=2, position=array([ 4.23537388,  0.0259258 , -1.14552878])), linker=AttachmentPoint(attachables={9}, attachment=9, position=array([ 3.60954021,  1.2186665 , -0.88750248])), bondtype=rdkit.Chem.rdchem.BondType.AROMATIC, bond_length=np.float64(1.3714502347627497), label=('Conn',), dihedral_plane_set=True)
# ==
# C(SINGLE:4)[PointCloud]<5740354900026072187>-3
# Primitive(shape=PointCloud, functionality=4, topology=TopologicalStructure(num_objects=0, indiscrete=True), element=C, label=3)
# 1
# SINGLE:4
# [-0.51033702  0.18413352 -0.52320043]
# Connector(anchor=AttachmentPoint(attachables={3}, attachment=3, position=array([ 5.23715537, -0.1922865 , -2.19947741])), linker=AttachmentPoint(attachables={2}, attachment=2, position=array([ 4.23537388,  0.0259258 , -1.14552878])), bondtype=rdkit.Chem.rdchem.BondType.SINGLE, bond_length=np.float64(1.4703708562505204), label=('Conn',), dihedral_plane_set=True)
# [-1.20504458  0.31633565  0.4854904 ]
# Connector(anchor=AttachmentPoint(attachables={3}, attachment=3, position=array([ 5.23715537, -0.1922865 , -2.19947741])), linker=AttachmentPoint(attachables={4}, attachment=4, position=array([ 4.96171097, -0.05931829, -2.96980234])), bondtype=rdkit.Chem.rdchem.BondType.SINGLE, bond_length=np.float64(0.8288248706497001), label=('Conn',), dihedral_plane_set=True)
# [-0.63652017  0.48813666  1.14214757]
# Connector(anchor=AttachmentPoint(attachables={3}, attachment=3, position=array([ 5.23715537, -0.1922865 , -2.19947741])), linker=AttachmentPoint(attachables={5}, attachment=5, position=array([ 6.43809279,  0.69519396, -1.90948935])), bondtype=rdkit.Chem.rdchem.BondType.SINGLE, bond_length=np.float64(1.5211723488426876), label=('Conn',), dihedral_plane_set=True)
# [-0.88602497 -0.19431016  1.07479526]
# Connector(anchor=AttachmentPoint(attachables={3}, attachment=3, position=array([ 5.23715537, -0.1922865 , -2.19947741])), linker=AttachmentPoint(attachables={29}, attachment=29, position=array([ 5.53648241, -1.25900075, -2.1455715 ])), bondtype=rdkit.Chem.rdchem.BondType.SINGLE, bond_length=np.float64(1.1092257758816917), label=('Conn',), dihedral_plane_set=True)
# ==
# C(SINGLE:4)[PointCloud]<5740354900026072187>-5
# Primitive(shape=PointCloud, functionality=4, topology=TopologicalStructure(num_objects=0, indiscrete=True), element=C, label=5)
# 1
# SINGLE:4
# [ 0.21384792 -0.77060333  1.47274142]
# Connector(anchor=AttachmentPoint(attachables={5}, attachment=5, position=array([ 6.43809279,  0.69519396, -1.90948935])), linker=AttachmentPoint(attachables={3}, attachment=3, position=array([ 5.23715537, -0.1922865 , -2.19947741])), bondtype=rdkit.Chem.rdchem.BondType.SINGLE, bond_length=np.float64(1.5211723488426876), label=('Conn',), dihedral_plane_set=True)
# [-1.0214225  -1.00860846  0.14173427]
# Connector(anchor=AttachmentPoint(attachables={5}, attachment=5, position=array([ 6.43809279,  0.69519396, -1.90948935])), linker=AttachmentPoint(attachables={6}, attachment=6, position=array([ 7.09495598,  0.25197437, -0.32977389])), bondtype=rdkit.Chem.rdchem.BondType.SINGLE, bond_length=np.float64(1.7673182503303382), label=('Conn',), dihedral_plane_set=True)
# [-0.88656788 -0.97948391 -0.60283385]
# Connector(anchor=AttachmentPoint(attachables={5}, attachment=5, position=array([ 6.43809279,  0.69519396, -1.90948935])), linker=AttachmentPoint(attachables={7}, attachment=7, position=array([ 7.78168005,  0.30197944, -3.24656426])), bondtype=rdkit.Chem.rdchem.BondType.SINGLE, bond_length=np.float64(1.935875430752037), label=('Conn',), dihedral_plane_set=True)
# [-1.33612319 -0.36267712 -0.32030114]
# Connector(anchor=AttachmentPoint(attachables={5}, attachment=5, position=array([ 6.43809279,  0.69519396, -1.90948935])), linker=AttachmentPoint(attachables={8}, attachment=8, position=array([ 6.09794842,  2.01566502, -1.98576089])), bondtype=rdkit.Chem.rdchem.BondType.SINGLE, bond_length=np.float64(1.3657083763436095), label=('Conn',), dihedral_plane_set=True)
# ==
# Cl(SINGLE:1)[PointCloud]<5740354900026072187>-6
# Primitive(shape=PointCloud, functionality=1, topology=TopologicalStructure(num_objects=0, indiscrete=True), element=Cl, label=6)
# 1
# SINGLE:1
# ==
# Br(SINGLE:1)[PointCloud]<5740354900026072187>-7
# Primitive(shape=PointCloud, functionality=1, topology=TopologicalStructure(num_objects=0, indiscrete=True), element=Br, label=7)
# 1
# SINGLE:1
# ==
# F(SINGLE:1)[PointCloud]<5740354900026072187>-8
# Primitive(shape=PointCloud, functionality=1, topology=TopologicalStructure(num_objects=0, indiscrete=True), element=F, label=8)
# 1
# SINGLE:1
# ==
# C(SINGLE:1-AROMATIC:2)[PointCloud]<5740354900026072187>-9
# Primitive(shape=PointCloud, functionality=3, topology=TopologicalStructure(num_objects=0, indiscrete=True), element=C, label=9)
# 1
# SINGLE:1-AROMATIC:2
# [-0.59921821 -0.50262481  0.87002814]
# Connector(anchor=AttachmentPoint(attachables={9}, attachment=9, position=array([ 3.60954021,  1.2186665 , -0.88750248])), linker=AttachmentPoint(attachables={2}, attachment=2, position=array([ 4.23537388,  0.0259258 , -1.14552878])), bondtype=rdkit.Chem.rdchem.BondType.AROMATIC, bond_length=np.float64(1.3714502347627497), label=('Conn',), dihedral_plane_set=True)
# [ 0.13268373 -1.12097878  0.27412575]
# Connector(anchor=AttachmentPoint(attachables={9}, attachment=9, position=array([ 3.60954021,  1.2186665 , -0.88750248])), linker=AttachmentPoint(attachables={10}, attachment=10, position=array([2.67525811, 1.35462087, 0.12066987])), bondtype=rdkit.Chem.rdchem.BondType.AROMATIC, bond_length=np.float64(1.3812234159167618), label=('Conn',), dihedral_plane_set=True)
# [ 0.77738152 -0.66999028 -0.62808389]
# Connector(anchor=AttachmentPoint(attachables={9}, attachment=9, position=array([ 3.60954021,  1.2186665 , -0.88750248])), linker=AttachmentPoint(attachables={30}, attachment=30, position=array([ 3.85837477,  2.07699856, -1.49511995])), bondtype=rdkit.Chem.rdchem.BondType.SINGLE, bond_length=np.float64(1.0806717990641646), label=('Conn',), dihedral_plane_set=True)
# ==
# C(SINGLE:1-AROMATIC:2)[PointCloud]<5740354900026072187>-10
# Primitive(shape=PointCloud, functionality=3, topology=TopologicalStructure(num_objects=0, indiscrete=True), element=C, label=10)
# 1
# SINGLE:1-AROMATIC:2
# [ 0.13373387 -1.12990551  0.27630271]
# Connector(anchor=AttachmentPoint(attachables={10}, attachment=10, position=array([2.67525811, 1.35462087, 0.12066987])), linker=AttachmentPoint(attachables={9}, attachment=9, position=array([ 3.60954021,  1.2186665 , -0.88750248])), bondtype=rdkit.Chem.rdchem.BondType.AROMATIC, bond_length=np.float64(1.3812234159167618), label=('Conn',), dihedral_plane_set=True)
# [ 0.74539724 -0.69521862 -0.58210027]
# Connector(anchor=AttachmentPoint(attachables={10}, attachment=10, position=array([2.67525811, 1.35462087, 0.12066987])), linker=AttachmentPoint(attachables={11}, attachment=11, position=array([2.31778709, 0.29619426, 0.92702575])), bondtype=rdkit.Chem.rdchem.BondType.AROMATIC, bond_length=np.float64(1.3777743814319556), label=('Conn',), dihedral_plane_set=True)
# [ 0.62402021  0.48247943 -0.89051984]
# Connector(anchor=AttachmentPoint(attachables={10}, attachment=10, position=array([2.67525811, 1.35462087, 0.12066987])), linker=AttachmentPoint(attachables={31}, attachment=31, position=array([2.19926755, 2.3033956 , 0.30116732])), bondtype=rdkit.Chem.rdchem.BondType.SINGLE, bond_length=np.float64(1.0767171504582629), label=('Conn',), dihedral_plane_set=True)
# ==
# C(SINGLE:1-AROMATIC:2)[PointCloud]<5740354900026072187>-11
# Primitive(shape=PointCloud, functionality=3, topology=TopologicalStructure(num_objects=0, indiscrete=True), element=C, label=11)
# 1
# SINGLE:1-AROMATIC:2
# [-0.91024898  0.84898994  0.71085971]
# Connector(anchor=AttachmentPoint(attachables={11}, attachment=11, position=array([2.31778709, 0.29619426, 0.92702575])), linker=AttachmentPoint(attachables={10}, attachment=10, position=array([2.67525811, 1.35462087, 0.12066987])), bondtype=rdkit.Chem.rdchem.BondType.AROMATIC, bond_length=np.float64(1.3777743814319556), label=('Conn',), dihedral_plane_set=True)
# [-0.16128396  1.10435789 -0.23536545]
# Connector(anchor=AttachmentPoint(attachables={11}, attachment=11, position=array([2.31778709, 0.29619426, 0.92702575])), linker=AttachmentPoint(attachables={12}, attachment=12, position=array([1.15555692, 0.3990997 , 2.20628541])), bondtype=rdkit.Chem.rdchem.BondType.SINGLE, bond_length=np.float64(1.7314369019634297), label=('Conn',), dihedral_plane_set=True)
# [ 0.6362407   0.51869295 -0.91809919]
# Connector(anchor=AttachmentPoint(attachables={11}, attachment=11, position=array([2.31778709, 0.29619426, 0.92702575])), linker=AttachmentPoint(attachables={0}, attachment=0, position=array([ 2.94176338, -0.91190346,  0.67690827])), bondtype=rdkit.Chem.rdchem.BondType.AROMATIC, bond_length=np.float64(1.3825358077677747), label=('Conn',), dihedral_plane_set=True)
# ==
# S(SINGLE:2-DOUBLE:2)[PointCloud]<5740354900026072187>-12
# Primitive(shape=PointCloud, functionality=4, topology=TopologicalStructure(num_objects=0, indiscrete=True), element=S, label=12)
# 1
# SINGLE:2-DOUBLE:2
# [ 0.748301   -0.96317202  0.75732368]
# Connector(anchor=AttachmentPoint(attachables={12}, attachment=12, position=array([1.15555692, 0.3990997 , 2.20628541])), linker=AttachmentPoint(attachables={11}, attachment=11, position=array([2.31778709, 0.29619426, 0.92702575])), bondtype=rdkit.Chem.rdchem.BondType.SINGLE, bond_length=np.float64(1.7314369019634297), label=('Conn',), dihedral_plane_set=True)
# [ 1.31681464 -0.45218516 -0.85786848]
# Connector(anchor=AttachmentPoint(attachables={12}, attachment=12, position=array([1.15555692, 0.3990997 , 2.20628541])), linker=AttachmentPoint(attachables={13}, attachment=13, position=array([ 1.56870477, -0.5343974 ,  3.33251011])), bondtype=rdkit.Chem.rdchem.BondType.DOUBLE, bond_length=np.float64(1.5200296305799894), label=('Conn',), dihedral_plane_set=True)
# [ 1.1829929   0.39547239 -1.07260728]
# Connector(anchor=AttachmentPoint(attachables={12}, attachment=12, position=array([1.15555692, 0.3990997 , 2.20628541])), linker=AttachmentPoint(attachables={14}, attachment=14, position=array([1.21315215, 1.78158566, 2.77953321])), bondtype=rdkit.Chem.rdchem.BondType.DOUBLE, bond_length=np.float64(1.4977308465793084), label=('Conn',), dihedral_plane_set=True)
# [ 0.55704664 -0.23525451 -1.48526926]
# Connector(anchor=AttachmentPoint(attachables={12}, attachment=12, position=array([1.15555692, 0.3990997 , 2.20628541])), linker=AttachmentPoint(attachables={15}, attachment=15, position=array([-0.46543787,  0.04460038,  1.65448503])), bondtype=rdkit.Chem.rdchem.BondType.SINGLE, bond_length=np.float64(1.7486502075757326), label=('Conn',), dihedral_plane_set=True)
# ==
# O(DOUBLE:1)[PointCloud]<5740354900026072187>-13
# Primitive(shape=PointCloud, functionality=1, topology=TopologicalStructure(num_objects=0, indiscrete=True), element=O, label=13)
# 1
# DOUBLE:1
# ==
# O(DOUBLE:1)[PointCloud]<5740354900026072187>-14
# Primitive(shape=PointCloud, functionality=1, topology=TopologicalStructure(num_objects=0, indiscrete=True), element=O, label=14)
# 1
# DOUBLE:1
# ==
# C(SINGLE:1-AROMATIC:2)[PointCloud]<5740354900026072187>-15
# Primitive(shape=PointCloud, functionality=3, topology=TopologicalStructure(num_objects=0, indiscrete=True), element=C, label=15)
# 1
# SINGLE:1-AROMATIC:2
# [-0.1638245   1.12092733 -0.23887137]
# Connector(anchor=AttachmentPoint(attachables={15}, attachment=15, position=array([-0.46543787,  0.04460038,  1.65448503])), linker=AttachmentPoint(attachables={12}, attachment=12, position=array([1.15555692, 0.3990997 , 2.20628541])), bondtype=rdkit.Chem.rdchem.BondType.SINGLE, bond_length=np.float64(1.7486502075757326), label=('Conn',), dihedral_plane_set=True)
# [1.02796046 1.02248646 0.22366081]
# Connector(anchor=AttachmentPoint(attachables={15}, attachment=15, position=array([-0.46543787,  0.04460038,  1.65448503])), linker=AttachmentPoint(attachables={16}, attachment=16, position=array([-1.32542655,  1.01328187,  1.17863346])), bondtype=rdkit.Chem.rdchem.BondType.AROMATIC, bond_length=np.float64(1.379985165392381), label=('Conn',), dihedral_plane_set=True)
# [ 1.39666151 -0.3926057   0.58593388]
# Connector(anchor=AttachmentPoint(attachables={15}, attachment=15, position=array([-0.46543787,  0.04460038,  1.65448503])), linker=AttachmentPoint(attachables={26}, attachment=26, position=array([-0.86504872, -1.28623766,  1.71528794])), bondtype=rdkit.Chem.rdchem.BondType.AROMATIC, bond_length=np.float64(1.390868694277973), label=('Conn',), dihedral_plane_set=True)
# ==
# C(SINGLE:1-AROMATIC:2)[PointCloud]<5740354900026072187>-16
# Primitive(shape=PointCloud, functionality=3, topology=TopologicalStructure(num_objects=0, indiscrete=True), element=C, label=16)
# 1
# SINGLE:1-AROMATIC:2
# [-0.85576461 -0.85120445 -0.18618856]
# Connector(anchor=AttachmentPoint(attachables={16}, attachment=16, position=array([-1.32542655,  1.01328187,  1.17863346])), linker=AttachmentPoint(attachables={15}, attachment=15, position=array([-0.46543787,  0.04460038,  1.65448503])), bondtype=rdkit.Chem.rdchem.BondType.AROMATIC, bond_length=np.float64(1.379985165392381), label=('Conn',), dihedral_plane_set=True)
# [ 0.25122186 -1.14967163  0.27620086]
# Connector(anchor=AttachmentPoint(attachables={16}, attachment=16, position=array([-1.32542655,  1.01328187,  1.17863346])), linker=AttachmentPoint(attachables={17}, attachment=17, position=array([-2.6003683 ,  0.6342338 ,  0.76050453])), bondtype=rdkit.Chem.rdchem.BondType.AROMATIC, bond_length=np.float64(1.3942688826509009), label=('Conn',), dihedral_plane_set=True)
# [ 1.06699993 -0.32794427  0.45206074]
# Connector(anchor=AttachmentPoint(attachables={16}, attachment=16, position=array([-1.32542655,  1.01328187,  1.17863346])), linker=AttachmentPoint(attachables={32}, attachment=32, position=array([-0.99299499,  2.04221759,  1.14042867])), bondtype=rdkit.Chem.rdchem.BondType.SINGLE, bond_length=np.float64(1.0819792396547212), label=('Conn',), dihedral_plane_set=True)
# ==
# C(SINGLE:1-AROMATIC:2)[PointCloud]<5740354900026072187>-17
# Primitive(shape=PointCloud, functionality=3, topology=TopologicalStructure(num_objects=0, indiscrete=True), element=C, label=17)
# 1
# SINGLE:1-AROMATIC:2
# [ 0.242102   -1.10793605  0.26617406]
# Connector(anchor=AttachmentPoint(attachables={17}, attachment=17, position=array([-2.6003683 ,  0.6342338 ,  0.76050453])), linker=AttachmentPoint(attachables={16}, attachment=16, position=array([-1.32542655,  1.01328187,  1.17863346])), bondtype=rdkit.Chem.rdchem.BondType.AROMATIC, bond_length=np.float64(1.3942688826509009), label=('Conn',), dihedral_plane_set=True)
# [ 1.04149863 -0.32838981  0.44256662]
# Connector(anchor=AttachmentPoint(attachables={17}, attachment=17, position=array([-2.6003683 ,  0.6342338 ,  0.76050453])), linker=AttachmentPoint(attachables={18}, attachment=18, position=array([-3.03207415, -0.6740295 ,  0.80569708])), bondtype=rdkit.Chem.rdchem.BondType.AROMATIC, bond_length=np.float64(1.3783922348525373), label=('Conn',), dihedral_plane_set=True)
# [0.90388387 0.83374161 0.20699998]
# Connector(anchor=AttachmentPoint(attachables={17}, attachment=17, position=array([-2.6003683 ,  0.6342338 ,  0.76050453])), linker=AttachmentPoint(attachables={33}, attachment=33, position=array([-3.23175575,  1.40793463,  0.40125016])), bondtype=rdkit.Chem.rdchem.BondType.SINGLE, bond_length=np.float64(1.0612854382947812), label=('Conn',), dihedral_plane_set=True)
# ==
# C(SINGLE:1-AROMATIC:2)[PointCloud]<5740354900026072187>-18
# Primitive(shape=PointCloud, functionality=3, topology=TopologicalStructure(num_objects=0, indiscrete=True), element=C, label=18)
# 1
# SINGLE:1-AROMATIC:2
# [-1.08035809  0.34064366 -0.4590427 ]
# Connector(anchor=AttachmentPoint(attachables={18}, attachment=18, position=array([-3.03207415, -0.6740295 ,  0.80569708])), linker=AttachmentPoint(attachables={17}, attachment=17, position=array([-2.6003683 ,  0.6342338 ,  0.76050453])), bondtype=rdkit.Chem.rdchem.BondType.AROMATIC, bond_length=np.float64(1.3783922348525373), label=('Conn',), dihedral_plane_set=True)
# [-0.25255206  1.09602781 -0.26818911]
# Connector(anchor=AttachmentPoint(attachables={18}, attachment=18, position=array([-3.03207415, -0.6740295 ,  0.80569708])), linker=AttachmentPoint(attachables={19}, attachment=19, position=array([-4.36083925, -1.08617103,  0.37265854])), bondtype=rdkit.Chem.rdchem.BondType.SINGLE, bond_length=np.float64(1.4570517184819494), label=('Conn',), dihedral_plane_set=True)
# [0.83447046 0.88699816 0.17253655]
# Connector(anchor=AttachmentPoint(attachables={18}, attachment=18, position=array([-3.03207415, -0.6740295 ,  0.80569708])), linker=AttachmentPoint(attachables={25}, attachment=25, position=array([-2.13947355, -1.60763066,  1.28822489])), bondtype=rdkit.Chem.rdchem.BondType.AROMATIC, bond_length=np.float64(1.3788328566822403), label=('Conn',), dihedral_plane_set=True)
# ==
# C(SINGLE:2-DOUBLE:1)[PointCloud]<5740354900026072187>-19
# Primitive(shape=PointCloud, functionality=3, topology=TopologicalStructure(num_objects=0, indiscrete=True), element=C, label=19)
# 1
# SINGLE:2-DOUBLE:1
# [-0.23994929  1.04125873 -0.25473423]
# Connector(anchor=AttachmentPoint(attachables={19}, attachment=19, position=array([-4.36083925, -1.08617103,  0.37265854])), linker=AttachmentPoint(attachables={18}, attachment=18, position=array([-3.03207415, -0.6740295 ,  0.80569708])), bondtype=rdkit.Chem.rdchem.BondType.SINGLE, bond_length=np.float64(1.4570517184819494), label=('Conn',), dihedral_plane_set=True)
# [0.77243767 0.92284128 0.14362173]
# Connector(anchor=AttachmentPoint(attachables={19}, attachment=19, position=array([-4.36083925, -1.08617103,  0.37265854])), linker=AttachmentPoint(attachables={20}, attachment=20, position=array([-5.26926315, -0.25225231, -0.09992855])), bondtype=rdkit.Chem.rdchem.BondType.DOUBLE, bond_length=np.float64(1.3206032688036342), label=('Conn',), dihedral_plane_set=True)
# [ 1.14897154 -0.27309858  0.47404629]
# Connector(anchor=AttachmentPoint(attachables={19}, attachment=19, position=array([-4.36083925, -1.08617103,  0.37265854])), linker=AttachmentPoint(attachables={34}, attachment=34, position=array([-4.63468595, -2.12987224,  0.43511816])), bondtype=rdkit.Chem.rdchem.BondType.SINGLE, bond_length=np.float64(1.0808355270674594), label=('Conn',), dihedral_plane_set=True)
# ==
# C(SINGLE:2-DOUBLE:1)[PointCloud]<5740354900026072187>-20
# Primitive(shape=PointCloud, functionality=3, topology=TopologicalStructure(num_objects=0, indiscrete=True), element=C, label=20)
# 1
# SINGLE:2-DOUBLE:1
# [-0.79296135 -0.94735892 -0.14743378]
# Connector(anchor=AttachmentPoint(attachables={20}, attachment=20, position=array([-5.26926315, -0.25225231, -0.09992855])), linker=AttachmentPoint(attachables={19}, attachment=19, position=array([-4.36083925, -1.08617103,  0.37265854])), bondtype=rdkit.Chem.rdchem.BondType.DOUBLE, bond_length=np.float64(1.3206032688036342), label=('Conn',), dihedral_plane_set=True)
# [ 0.27365613 -1.05125498  0.2689572 ]
# Connector(anchor=AttachmentPoint(attachables={20}, attachment=20, position=array([-5.26926315, -0.25225231, -0.09992855])), linker=AttachmentPoint(attachables={21}, attachment=21, position=array([-6.59846277, -0.70735301, -0.52632821])), bondtype=rdkit.Chem.rdchem.BondType.SINGLE, bond_length=np.float64(1.46823190896597), label=('Conn',), dihedral_plane_set=True)
# [ 1.03380824 -0.1539152   0.41200401]
# Connector(anchor=AttachmentPoint(attachables={20}, attachment=20, position=array([-5.26926315, -0.25225231, -0.09992855])), linker=AttachmentPoint(attachables={35}, attachment=35, position=array([-5.07557233,  0.79820149, -0.19351589])), bondtype=rdkit.Chem.rdchem.BondType.SINGLE, bond_length=np.float64(1.0722536587026898), label=('Conn',), dihedral_plane_set=True)
# ==
# C(SINGLE:2-DOUBLE:1)[PointCloud]<5740354900026072187>-21
# Primitive(shape=PointCloud, functionality=3, topology=TopologicalStructure(num_objects=0, indiscrete=True), element=C, label=21)
# 1
# SINGLE:2-DOUBLE:1
# [-0.2724413   1.04658576 -0.26776065]
# Connector(anchor=AttachmentPoint(attachables={21}, attachment=21, position=array([-6.59846277, -0.70735301, -0.52632821])), linker=AttachmentPoint(attachables={20}, attachment=20, position=array([-5.26926315, -0.25225231, -0.09992855])), bondtype=rdkit.Chem.rdchem.BondType.SINGLE, bond_length=np.float64(1.46823190896597), label=('Conn',), dihedral_plane_set=True)
# [0.77920641 0.94916039 0.14199233]
# Connector(anchor=AttachmentPoint(attachables={21}, attachment=21, position=array([-6.59846277, -0.70735301, -0.52632821])), linker=AttachmentPoint(attachables={22}, attachment=22, position=array([-7.51719953,  0.11794956, -1.00141677])), bondtype=rdkit.Chem.rdchem.BondType.DOUBLE, bond_length=np.float64(1.3232198284273964), label=('Conn',), dihedral_plane_set=True)
# [ 1.2051307  -0.19019059  0.48198431]
# Connector(anchor=AttachmentPoint(attachables={21}, attachment=21, position=array([-6.59846277, -0.70735301, -0.52632821])), linker=AttachmentPoint(attachables={36}, attachment=36, position=array([-6.80494222, -1.78126744, -0.43382247])), bondtype=rdkit.Chem.rdchem.BondType.SINGLE, bond_length=np.float64(1.0974895345004383), label=('Conn',), dihedral_plane_set=True)
# ==
# C(SINGLE:2-DOUBLE:1)[PointCloud]<5740354900026072187>-22
# Primitive(shape=PointCloud, functionality=3, topology=TopologicalStructure(num_objects=0, indiscrete=True), element=C, label=22)
# 1
# SINGLE:2-DOUBLE:1
# [0.75876158 0.92425814 0.13826991]
# Connector(anchor=AttachmentPoint(attachables={22}, attachment=22, position=array([-7.51719953,  0.11794956, -1.00141677])), linker=AttachmentPoint(attachables={21}, attachment=21, position=array([-6.59846277, -0.70735301, -0.52632821])), bondtype=rdkit.Chem.rdchem.BondType.DOUBLE, bond_length=np.float64(1.3232198284273964), label=('Conn',), dihedral_plane_set=True)
# [ 1.0574411  -0.20420684  0.42882317]
# Connector(anchor=AttachmentPoint(attachables={22}, attachment=22, position=array([-7.51719953,  0.11794956, -1.00141677])), linker=AttachmentPoint(attachables={23}, attachment=23, position=array([-7.21849925,  1.45548143, -1.10104945])), bondtype=rdkit.Chem.rdchem.BondType.SINGLE, bond_length=np.float64(1.3740960832832438), label=('Conn',), dihedral_plane_set=True)
# [ 0.34282159 -1.06124393  0.29646886]
# Connector(anchor=AttachmentPoint(attachables={22}, attachment=22, position=array([-7.51719953,  0.11794956, -1.00141677])), linker=AttachmentPoint(attachables={37}, attachment=37, position=array([-8.4603718 , -0.26844996, -1.29394101])), bondtype=rdkit.Chem.rdchem.BondType.SINGLE, bond_length=np.float64(1.0604003663560135), label=('Conn',), dihedral_plane_set=True)
# ==
# O(SINGLE:2)[PointCloud]<5740354900026072187>-23
# Primitive(shape=PointCloud, functionality=2, topology=TopologicalStructure(num_objects=0, indiscrete=True), element=O, label=23)
# 1
# SINGLE:2
# [ 0.56439703 -0.12083005  0.0699721 ]
# Connector(anchor=AttachmentPoint(attachables={23}, attachment=23, position=array([-7.21849925,  1.45548143, -1.10104945])), linker=AttachmentPoint(attachables={22}, attachment=22, position=array([-7.51719953,  0.11794956, -1.00141677])), bondtype=rdkit.Chem.rdchem.BondType.SINGLE, bond_length=np.float64(1.3740960832832438), label=('Conn',), dihedral_plane_set=True)
# [ 0.45671421 -0.97880508  0.14253497]
# Connector(anchor=AttachmentPoint(attachables={23}, attachment=23, position=array([-7.21849925,  1.45548143, -1.10104945])), linker=AttachmentPoint(attachables={24}, attachment=24, position=array([-6.55696233,  1.7696282 , -1.06347876])), bondtype=rdkit.Chem.rdchem.BondType.SINGLE, bond_length=np.float64(0.733301334921532), label=('Conn',), dihedral_plane_set=True)
# ==
# C(SINGLE:1-AROMATIC:2)[PointCloud]<5740354900026072187>-25
# Primitive(shape=PointCloud, functionality=3, topology=TopologicalStructure(num_objects=0, indiscrete=True), element=C, label=25)
# 1
# SINGLE:1-AROMATIC:2
# [0.78447094 0.83385236 0.16220061]
# Connector(anchor=AttachmentPoint(attachables={25}, attachment=25, position=array([-2.13947355, -1.60763066,  1.28822489])), linker=AttachmentPoint(attachables={18}, attachment=18, position=array([-3.03207415, -0.6740295 ,  0.80569708])), bondtype=rdkit.Chem.rdchem.BondType.AROMATIC, bond_length=np.float64(1.3788328566822403), label=('Conn',), dihedral_plane_set=True)
# [-0.19623121  1.10921627 -0.24917262]
# Connector(anchor=AttachmentPoint(attachables={25}, attachment=25, position=array([-2.13947355, -1.60763066,  1.28822489])), linker=AttachmentPoint(attachables={26}, attachment=26, position=array([-0.86504872, -1.28623766,  1.71528794])), bondtype=rdkit.Chem.rdchem.BondType.AROMATIC, bond_length=np.float64(1.3819677867971853), label=('Conn',), dihedral_plane_set=True)
# [-1.080208    0.29639553 -0.45202005]
# Connector(anchor=AttachmentPoint(attachables={25}, attachment=25, position=array([-2.13947355, -1.60763066,  1.28822489])), linker=AttachmentPoint(attachables={38}, attachment=38, position=array([-2.44425578, -2.64281878,  1.33778701])), bondtype=rdkit.Chem.rdchem.BondType.SINGLE, bond_length=np.float64(1.080260642877649), label=('Conn',), dihedral_plane_set=True)
# ==
# C(SINGLE:1-AROMATIC:2)[PointCloud]<5740354900026072187>-26
# Primitive(shape=PointCloud, functionality=3, topology=TopologicalStructure(num_objects=0, indiscrete=True), element=C, label=26)
# 1
# SINGLE:1-AROMATIC:2
# [-0.2083152   1.17752718 -0.26452051]
# Connector(anchor=AttachmentPoint(attachables={26}, attachment=26, position=array([-0.86504872, -1.28623766,  1.71528794])), linker=AttachmentPoint(attachables={25}, attachment=25, position=array([-2.13947355, -1.60763066,  1.28822489])), bondtype=rdkit.Chem.rdchem.BondType.AROMATIC, bond_length=np.float64(1.3819677867971853), label=('Conn',), dihedral_plane_set=True)
# [-1.08623447  0.30534396 -0.45569722]
# Connector(anchor=AttachmentPoint(attachables={26}, attachment=26, position=array([-0.86504872, -1.28623766,  1.71528794])), linker=AttachmentPoint(attachables={15}, attachment=15, position=array([-0.46543787,  0.04460038,  1.65448503])), bondtype=rdkit.Chem.rdchem.BondType.AROMATIC, bond_length=np.float64(1.390868694277973), label=('Conn',), dihedral_plane_set=True)
# [-0.85763502 -0.81524496 -0.19258096]
# Connector(anchor=AttachmentPoint(attachables={26}, attachment=26, position=array([-0.86504872, -1.28623766,  1.71528794])), linker=AttachmentPoint(attachables={39}, attachment=39, position=array([-0.20404751, -2.06945437,  2.08716112])), bondtype=rdkit.Chem.rdchem.BondType.SINGLE, bond_length=np.float64(1.0902479892912722), label=('Conn',), dihedral_plane_set=True)
# ==
# H(SINGLE:1)[PointCloud]<5740354900026072187>-27
# Primitive(shape=PointCloud, functionality=1, topology=TopologicalStructure(num_objects=0, indiscrete=True), element=H, label=27)
# 1
# SINGLE:1
# ==
# H(SINGLE:1)[PointCloud]<5740354900026072187>-28
# Primitive(shape=PointCloud, functionality=1, topology=TopologicalStructure(num_objects=0, indiscrete=True), element=H, label=28)
# 1
# SINGLE:1
# ==
# H(SINGLE:1)[PointCloud]<5740354900026072187>-29
# Primitive(shape=PointCloud, functionality=1, topology=TopologicalStructure(num_objects=0, indiscrete=True), element=H, label=29)
# 1
# SINGLE:1
# ==
# H(SINGLE:1)[PointCloud]<5740354900026072187>-30
# Primitive(shape=PointCloud, functionality=1, topology=TopologicalStructure(num_objects=0, indiscrete=True), element=H, label=30)
# 1
# SINGLE:1
# ==
# H(SINGLE:1)[PointCloud]<5740354900026072187>-31
# Primitive(shape=PointCloud, functionality=1, topology=TopologicalStructure(num_objects=0, indiscrete=True), element=H, label=31)
# 1
# SINGLE:1
# ==
# H(SINGLE:1)[PointCloud]<5740354900026072187>-32
# Primitive(shape=PointCloud, functionality=1, topology=TopologicalStructure(num_objects=0, indiscrete=True), element=H, label=32)
# 1
# SINGLE:1
# ==
# H(SINGLE:1)[PointCloud]<5740354900026072187>-33
# Primitive(shape=PointCloud, functionality=1, topology=TopologicalStructure(num_objects=0, indiscrete=True), element=H, label=33)
# 1
# SINGLE:1
# ==
# H(SINGLE:1)[PointCloud]<5740354900026072187>-34
# Primitive(shape=PointCloud, functionality=1, topology=TopologicalStructure(num_objects=0, indiscrete=True), element=H, label=34)
# 1
# SINGLE:1
# ==
# H(SINGLE:1)[PointCloud]<5740354900026072187>-35
# Primitive(shape=PointCloud, functionality=1, topology=TopologicalStructure(num_objects=0, indiscrete=True), element=H, label=35)
# 1
# SINGLE:1
# ==
# H(SINGLE:1)[PointCloud]<5740354900026072187>-36
# Primitive(shape=PointCloud, functionality=1, topology=TopologicalStructure(num_objects=0, indiscrete=True), element=H, label=36)
# 1
# SINGLE:1
# ==
# H(SINGLE:1)[PointCloud]<5740354900026072187>-37
# Primitive(shape=PointCloud, functionality=1, topology=TopologicalStructure(num_objects=0, indiscrete=True), element=H, label=37)
# 1
# SINGLE:1
# ==
# H(SINGLE:1)[PointCloud]<5740354900026072187>-38
# Primitive(shape=PointCloud, functionality=1, topology=TopologicalStructure(num_objects=0, indiscrete=True), element=H, label=38)
# 1
# SINGLE:1
# ==
# H(SINGLE:1)[PointCloud]<5740354900026072187>-39
# Primitive(shape=PointCloud, functionality=1, topology=TopologicalStructure(num_objects=0, indiscrete=True), element=H, label=39)
# 1
# SINGLE:1
# ==

# %% [markdown]
# ## Export to RDKit

# %%
from mupt.interfaces.rdkit import primitive_to_rdkit

outmol = primitive_to_rdkit(prim)
display(outmol)

# %% [markdown]
# N.B: all unset atom positions (e.g. when no conformer is provided) will be collapsed to the same point (by default the origin)
# Depending on how small the molecule is, these can be nevertheless recovered by RDKit's coordinate embedding

# %%
# zwitterionic phenylalanine
smi = '*-[NH2+][13CH](C(=O)[O-])Cc1ccc(-*)cc1'
mol = Chem.MolFromSmiles(smi)
mol = Chem.AddHs(mol)
display(mol)

newprim = primitive_from_rdkit(mol)
outmol = primitive_to_rdkit(newprim)
display(outmol)

# %%
from rdkit.Chem.rdDepictor import Compute2DCoords

conf_id = Compute2DCoords(outmol)
display(outmol)
